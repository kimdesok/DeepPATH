# %% [markdown]
# <a href="https://colab.research.google.com/github/kimdesok/DeepPATH/blob/master/Tiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ##	Objective:
# >* Tile svs, jpg or dcm images with the possibility of rejecting some tiles based based on xml or jpg masks
#
# File name: 0b_tileLoop_deepzoom.py
# Date created: March/2017
#
# > Source:
# 	Tiling code inspired from
# 	https://github.com/openslide/openslide-python/blob/master/examples/deepzoom/deepzoom_tile.py
# 	which is Copyright (c) 2010-2015 Carnegie Mellon University
# 	The code has been extensively modified
#
# > Be careful:
# 	Overload of the node - may have memory issue if node is shared with other jobs.
# '''
#    File name: 0b_tileLoop_deepzoom.py
#     Date created: March/2017

# %%
# !cp /content/drive/MyDrive/GDC/images.tar .

# %%
# !cp /content/drive/MyDrive/GDC/requirements.txt .

# %%
# !tar xvf images.tar
# Out:
# content/Images/
# content/Images/68ea3f6b-df81-4f87-9e06-388bb786ffae/
# content/Images/68ea3f6b-df81-4f87-9e06-388bb786ffae/logs/
# content/Images/68ea3f6b-df81-4f87-9e06-388bb786ffae/logs/TCGA-56-8307-01A-01-TS1.7537de75-53be-4ace-aec7-0a6119eb5144.svs.parcel
# content/Images/68ea3f6b-df81-4f87-9e06-388bb786ffae/TCGA-56-8307-01A-01-TS1.7537de75-53be-4ace-aec7-0a6119eb5144.svs
# content/Images/32cc4f1b-c416-4689-980a-78624d89d4eb/
# content/Images/32cc4f1b-c416-4689-980a-78624d89d4eb/logs/
# content/Images/32cc4f1b-c416-4689-980a-78624d89d4eb/logs/TCGA-44-2655-11A-01-TS1.1f824b99-5455-4bab-b491-e993d9f370af.svs.parcel
# content/Images/32cc4f1b-c416-4689-980a-78624d89d4eb/TCGA-44-2655-11A-01-TS1.1f824b99-5455-4bab-b491-e993d9f370af.svs
# content/Images/bcdf3222-020c-40aa-89ab-c8273bd383f2/
# content/Images/bcdf3222-020c-40aa-89ab-c8273bd383f2/logs/
# content/Images/bcdf3222-020c-40aa-89ab-c8273bd383f2/logs/TCGA-21-1080-01A-01-BS1.07776f13-668c-44a8-ad9e-1d967efc1c76.svs.parcel
# content/Images/bcdf3222-020c-40aa-89ab-c8273bd383f2/TCGA-21-1080-01A-01-BS1.07776f13-668c-44a8-ad9e-1d967efc1c76.svs
# content/Images/2263e5d9-d2d7-4dce-a4e6-9edef7519e9e/
# content/Images/2263e5d9-d2d7-4dce-a4e6-9edef7519e9e/logs/
# content/Images/2263e5d9-d2d7-4dce-a4e6-9edef7519e9e/logs/TCGA-49-4505-11A-01-BS1.e019788b-29ba-4469-bda7-c39824386c12.svs.parcel
# content/Images/2263e5d9-d2d7-4dce-a4e6-9edef7519e9e/TCGA-49-4505-11A-01-BS1.e019788b-29ba-4469-bda7-c39824386c12.svs
# content/Images/1b640e99-3ed0-42bc-8e2c-2dccf789a283/
# content/Images/1b640e99-3ed0-42bc-8e2c-2dccf789a283/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848.svs
# content/Images/1b640e99-3ed0-42bc-8e2c-2dccf789a283/logs/
# content/Images/1b640e99-3ed0-42bc-8e2c-2dccf789a283/logs/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848.svs.parcel
# content/Images/5647b3ab-ae91-4bd3-8179-bcf3d1f85317/
# content/Images/5647b3ab-ae91-4bd3-8179-bcf3d1f85317/logs/
# content/Images/5647b3ab-ae91-4bd3-8179-bcf3d1f85317/logs/TCGA-85-A4JB-01A-05-TSE.9AF21BB3-E3E2-47CE-8BF6-025A1BC6FD96.svs.parcel
# content/Images/5647b3ab-ae91-4bd3-8179-bcf3d1f85317/TCGA-85-A4JB-01A-05-TSE.9AF21BB3-E3E2-47CE-8BF6-025A1BC6FD96.svs

# %% [markdown]
# ##Libraries

# %%
# !pip install -r requirements.txt
# Out:
# Collecting absl-py==0.2.2
#   Downloading absl-py-0.2.2.tar.gz (82 kB)
#      |████████████████████████████████| 82 kB 831 kB/s
# Collecting alabaster==0.7.11
#   Downloading alabaster-0.7.11-py2.py3-none-any.whl (14 kB)
# Collecting allennlp==0.7.1
#   Downloading allennlp-0.7.1-py3-none-any.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 38.4 MB/s
# Collecting apex==0.9.10.dev0
#   Downloading apex-0.9.10dev.tar.gz (36 kB)
# Collecting appdirs==1.4.3
#   Downloading appdirs-1.4.3-py2.py3-none-any.whl (12 kB)
# Collecting asn1crypto==0.24.0
#   Downloading asn1crypto-0.24.0-py2.py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 8.4 MB/s
# Collecting astor==0.6.2
#   Downloading astor-0.6.2-py2.py3-none-any.whl (26 kB)
# Collecting atomicwrites==1.1.5
#   Downloading atomicwrites-1.1.5-py2.py3-none-any.whl (7.5 kB)
# Collecting attrs==18.1.0
#   Downloading attrs-18.1.0-py2.py3-none-any.whl (28 kB)
# Collecting aws-xray-sdk==0.95
#   Downloading aws_xray_sdk-0.95-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.3 MB/s
# Collecting awscli==1.15.77
#   Downloading awscli-1.15.77-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 57.9 MB/s
# Collecting Babel==2.6.0
#   Downloading Babel-2.6.0-py2.py3-none-any.whl (8.1 MB)
#      |████████████████████████████████| 8.1 MB 35.5 MB/s
# Collecting backcall==0.1.0
#   Downloading backcall-0.1.0.zip (11 kB)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 4.6 MB/s
# Collecting biopython==1.72
#   Downloading biopython-1.72.tar.gz (16.4 MB)
#      |████████████████████████████████| 16.4 MB 278 kB/s
# Collecting bleach==1.5.0
#   Downloading bleach-1.5.0-py2.py3-none-any.whl (17 kB)
# Collecting boto==2.49.0
#   Downloading boto-2.49.0-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 57.8 MB/s
# Collecting boto3==1.9.43
#   Downloading boto3-1.9.43-py2.py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 53.9 MB/s
# Collecting botocore==1.12.43
#   Downloading botocore-1.12.43-py2.py3-none-any.whl (4.8 MB)
#      |████████████████████████████████| 4.8 MB 44.2 MB/s
# Collecting bz2file==0.98
#   Downloading bz2file-0.98.tar.gz (11 kB)
# Collecting certifi==2018.4.16
#   Downloading certifi-2018.4.16-py2.py3-none-any.whl (150 kB)
#      |████████████████████████████████| 150 kB 52.3 MB/s
# Collecting cffi==1.11.2
#   Downloading cffi-1.11.2.tar.gz (435 kB)
#      |████████████████████████████████| 435 kB 58.3 MB/s
# Collecting chainer==7.4.0
#   Downloading chainer-7.4.0.tar.gz (1.0 MB)
#      |████████████████████████████████| 1.0 MB 63.7 MB/s
# Requirement already satisfied: chardet==3.0.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 24)) (3.0.4)
# Collecting click==6.7
#   Downloading click-6.7-py2.py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 7.0 MB/s
# Collecting cloudpickle==0.5.3
#   Downloading cloudpickle-0.5.3-py2.py3-none-any.whl (13 kB)
# Collecting colorama==0.3.9
#   Downloading colorama-0.3.9-py2.py3-none-any.whl (20 kB)
# Collecting conllu==0.11
#   Downloading conllu-0.11-py2.py3-none-any.whl (6.8 kB)
# Collecting cookies==2.2.1
#   Downloading cookies-2.2.1-py2.py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 2.4 MB/s
# Collecting cryptography==2.4.1
#   Downloading cryptography-2.4.1-cp34-abi3-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 35.0 MB/s
# Collecting csbdeep==0.6.2
#   Downloading csbdeep-0.6.2-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 891 kB/s
# Collecting cupy==7.5.0
#   Downloading cupy-7.5.0.tar.gz (3.7 MB)
#      |████████████████████████████████| 3.7 MB 50.9 MB/s
# Collecting cupy-cuda90==7.5.0
#   Downloading cupy_cuda90-7.5.0-cp37-cp37m-manylinux1_x86_64.whl (297.3 MB)
#      |████████████████████████████████| 297.3 MB 25 kB/s
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting cymem==1.31.2
#   Downloading cymem-1.31.2.tar.gz (33 kB)
# Collecting Cython==0.28.4
#   Downloading Cython-0.28.4-cp37-cp37m-manylinux1_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 9.8 MB/s
# Collecting cytoolz==0.9.0.1
#   Downloading cytoolz-0.9.0.1.tar.gz (443 kB)
#      |████████████████████████████████| 443 kB 26.2 MB/s
# Collecting dask==0.18.2
#   Downloading dask-0.18.2-py2.py3-none-any.whl (645 kB)
#      |████████████████████████████████| 645 kB 39.3 MB/s
# Collecting decorator==4.3.0
#   Downloading decorator-4.3.0-py2.py3-none-any.whl (9.2 kB)
# Collecting dicom==0.9.9.post1
#   Downloading dicom-0.9.9.post1-py3-none-any.whl (766 kB)
#      |████████████████████████████████| 766 kB 39.5 MB/s
# Collecting dill==0.2.8.2
#   Downloading dill-0.2.8.2.tar.gz (150 kB)
#      |████████████████████████████████| 150 kB 38.1 MB/s
# Collecting distributed==1.23.2
#   Downloading distributed-1.23.2-py2.py3-none-any.whl (499 kB)
#      |████████████████████████████████| 499 kB 51.4 MB/s
# Collecting Django==2.1.1
#   Downloading Django-2.1.1-py3-none-any.whl (7.3 MB)
#      |████████████████████████████████| 7.3 MB 30.0 MB/s
# Collecting docker==3.5.1
#   Downloading docker-3.5.1-py2.py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 63.5 MB/s
# Collecting docker-pycreds==0.3.0
#   Downloading docker_pycreds-0.3.0-py2.py3-none-any.whl (5.4 kB)
# Collecting docutils==0.14
#   Downloading docutils-0.14-py3-none-any.whl (543 kB)
#      |████████████████████████████████| 543 kB 53.4 MB/s
# Collecting ecdsa==0.13
#   Downloading ecdsa-0.13-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 3.8 MB/s
# Collecting editdistance==0.4
#   Downloading editdistance-0.4.tar.gz (20 kB)
# Collecting entrypoints==0.2.3
#   Downloading entrypoints-0.2.3-py2.py3-none-any.whl (9.4 kB)
# Collecting fastrlock==0.5
#   Downloading fastrlock-0.5-cp37-cp37m-manylinux1_x86_64.whl (31 kB)
# Collecting filelock==3.0.12
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Collecting flaky==3.4.0
#   Downloading flaky-3.4.0-py2.py3-none-any.whl (27 kB)
# Collecting Flask==0.12.4
#   Downloading Flask-0.12.4-py2.py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 7.7 MB/s
# Collecting Flask-Cors==3.0.3
#   Downloading Flask_Cors-3.0.3-py2.py3-none-any.whl (15 kB)
# Collecting ftfy==5.5.0
#   Downloading ftfy-5.5.0.tar.gz (56 kB)
#      |████████████████████████████████| 56 kB 4.2 MB/s
# Collecting funcsigs==1.0.2
#   Downloading funcsigs-1.0.2-py2.py3-none-any.whl (17 kB)
# Collecting future==0.17.1
#   Downloading future-0.17.1.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 54.6 MB/s
# Collecting gast==0.2.0
#   Downloading gast-0.2.0.tar.gz (9.4 kB)
# Collecting gevent==1.3.6
#   Downloading gevent-1.3.6-cp37-cp37m-manylinux1_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 44.7 MB/s
# Collecting Glymur==0.8.16
#   Downloading Glymur-0.8.16.tar.gz (3.4 MB)
#      |████████████████████████████████| 3.4 MB 34.5 MB/s
# Collecting greenlet==0.4.14
#   Downloading greenlet-0.4.14-cp37-cp37m-manylinux1_x86_64.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.1 MB/s
# Collecting grpcio==1.12.0
#   Downloading grpcio-1.12.0.tar.gz (14.2 MB)
#      |████████████████████████████████| 14.2 MB 33.5 MB/s
# Collecting h5py==2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 36.6 MB/s
# Collecting HeapDict==1.0.0
#   Downloading HeapDict-1.0.0-py3-none-any.whl (3.9 kB)
# Collecting html5lib==0.9999999
#   Downloading html5lib-0.9999999.tar.gz (889 kB)
#      |████████████████████████████████| 889 kB 32.6 MB/s
# Collecting idna==2.7
#   Downloading idna-2.7-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 204 kB/s
# Collecting image==1.5.25
#   Downloading image-1.5.25-py2.py3-none-any.whl (19 kB)
# Collecting imageio==2.8.0
#   Downloading imageio-2.8.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 34.1 MB/s
# Collecting imagesize==1.0.0
#   Downloading imagesize-1.0.0-py2.py3-none-any.whl (5.0 kB)
# Collecting importlib==1.0.4
#   Downloading importlib-1.0.4.zip (7.1 kB)
# Collecting ipykernel==4.8.2
#   Downloading ipykernel-4.8.2-py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 57.0 MB/s
# Collecting ipython==6.4.0
#   Downloading ipython-6.4.0-py3-none-any.whl (750 kB)
#      |████████████████████████████████| 750 kB 67.5 MB/s
# Requirement already satisfied: ipython-genutils==0.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 75)) (0.2.0)
# Collecting ipywidgets==7.3.0
#   Downloading ipywidgets-7.3.0-py2.py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 63.2 MB/s
# Collecting isodate==0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 2.8 MB/s
# Collecting itsdangerous==0.24
#   Downloading itsdangerous-0.24.tar.gz (46 kB)
#      |████████████████████████████████| 46 kB 3.1 MB/s
# Collecting jedi==0.12.1
#   Downloading jedi-0.12.1-py2.py3-none-any.whl (174 kB)
#      |████████████████████████████████| 174 kB 48.9 MB/s
# Collecting Jinja2==2.10
#   Downloading Jinja2-2.10-py2.py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 66.8 MB/s
# Collecting jmespath==0.9.3
#   Downloading jmespath-0.9.3-py2.py3-none-any.whl (23 kB)
# Collecting joblib==0.13.2
#   Downloading joblib-0.13.2-py2.py3-none-any.whl (278 kB)
#      |████████████████████████████████| 278 kB 71.0 MB/s
# Collecting jsondiff==1.1.1
#   Downloading jsondiff-1.1.1.tar.gz (7.8 kB)
# Collecting jsonnet==0.10.0
#   Downloading jsonnet-0.10.0.tar.gz (124 kB)
#      |████████████████████████████████| 124 kB 63.0 MB/s
# Collecting jsonpickle==1.0
#   Downloading jsonpickle-1.0-py3-none-any.whl (30 kB)
# Requirement already satisfied: jsonschema==2.6.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 86)) (2.6.0)
# Requirement already satisfied: jupyter==1.0.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 87)) (1.0.0)
# Collecting jupyter-client==5.2.3
#   Downloading jupyter_client-5.2.3-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 7.0 MB/s
# Requirement already satisfied: jupyter-console==5.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 89)) (5.2.0)
# Collecting jupyter-core==4.4.0
#   Downloading jupyter_core-4.4.0-py2.py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 57.3 MB/s
# Collecting Keras==2.2.4
#   Downloading Keras-2.2.4-py2.py3-none-any.whl (312 kB)
#      |████████████████████████████████| 312 kB 63.2 MB/s
# Collecting Keras-Applications==1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 5.5 MB/s
# Collecting Keras-Preprocessing==1.1.0
#   Downloading Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 555 kB/s
# Collecting kiwisolver==1.0.1
#   Downloading kiwisolver-1.0.1-cp37-cp37m-manylinux1_x86_64.whl (89 kB)
#      |████████████████████████████████| 89 kB 7.1 MB/s
# Collecting lightgbm==2.3.1
#   Downloading lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 38.3 MB/s
# Collecting llvmlite==0.36.0
#   Downloading llvmlite-0.36.0-cp37-cp37m-manylinux2010_x86_64.whl (25.3 MB)
#      |████████████████████████████████| 25.3 MB 1.6 MB/s
# Collecting locket==0.2.0
#   Downloading locket-0.2.0.tar.gz (3.5 kB)
# Collecting logomaker==0.8
#   Downloading logomaker-0.8-py2.py3-none-any.whl (11.8 MB)
#      |████████████████████████████████| 11.8 MB 36.4 MB/s
# Collecting lxml==4.3.2
#   Downloading lxml-4.3.2-cp37-cp37m-manylinux1_x86_64.whl (5.7 MB)
#      |████████████████████████████████| 5.7 MB 25.5 MB/s
# Collecting m2r==0.2.1
#   Downloading m2r-0.2.1.tar.gz (16 kB)
# Collecting Mako==1.0.7
#   Downloading Mako-1.0.7.tar.gz (564 kB)
#      |████████████████████████████████| 564 kB 36.9 MB/s
# Collecting Markdown==2.6.11
#   Downloading Markdown-2.6.11-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 4.3 MB/s
# Requirement already satisfied: MarkupSafe==2.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 103)) (2.0.1)
# Requirement already satisfied: matplotlib==3.2.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 104)) (3.2.2)
# Collecting mistune==0.8.3
#   Downloading mistune-0.8.3-py2.py3-none-any.whl (16 kB)
# Collecting mock==2.0.0
#   Downloading mock-2.0.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 2.8 MB/s
# Collecting more-itertools==4.3.0
#   Downloading more_itertools-4.3.0-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 3.9 MB/s
# Collecting moto==1.3.4
#   Downloading moto-1.3.4-py2.py3-none-any.whl (548 kB)
#      |████████████████████████████████| 548 kB 56.9 MB/s
# Collecting mpi4py==3.0.3
#   Downloading mpi4py-3.0.3.tar.gz (1.4 MB)
#      |████████████████████████████████| 1.4 MB 67.7 MB/s
# Collecting msgpack==0.5.6
#   Downloading msgpack-0.5.6.tar.gz (138 kB)
#      |████████████████████████████████| 138 kB 59.8 MB/s
# Collecting msgpack-numpy==0.4.3.1
#   Downloading msgpack_numpy-0.4.3.1-py2.py3-none-any.whl (5.3 kB)
# Collecting multiprocess==0.70.6.1
#   Downloading multiprocess-0.70.6.1.tar.gz (1.4 MB)
#      |████████████████████████████████| 1.4 MB 45.0 MB/s
# Collecting murmurhash==0.28.0
#   Downloading murmurhash-0.28.0.tar.gz (23 kB)
# Collecting nbconvert==5.3.1
#   Downloading nbconvert-5.3.1-py2.py3-none-any.whl (387 kB)
#      |████████████████████████████████| 387 kB 42.0 MB/s
# Collecting nbformat==4.4.0
#   Downloading nbformat-4.4.0-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 53.1 MB/s
# Collecting networkx==2.1
#   Downloading networkx-2.1.zip (1.6 MB)
#      |████████████████████████████████| 1.6 MB 43.6 MB/s
# Collecting neurdflib==5.0.0.post1
#   Downloading neurdflib-5.0.0.post1-py2.py3-none-any.whl (336 kB)
#      |████████████████████████████████| 336 kB 58.3 MB/s
# Collecting nibabel==2.3.3
#   Downloading nibabel-2.3.3-py3-none-any.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 45.6 MB/s
# Collecting nilearn==0.5.0
#   Downloading nilearn-0.5.0-py2.py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 44.0 MB/s
# Collecting nimfa==1.4.0
#   Downloading nimfa-1.4.0-py2.py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 52.6 MB/s
# Collecting nipype==1.1.9
#   Downloading nipype-1.1.9-py2.py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 47.4 MB/s
# Collecting nltk==3.3
#   Downloading nltk-3.3.0.zip (1.4 MB)
#      |████████████████████████████████| 1.4 MB 33.9 MB/s
# Collecting notebook==5.6.0
#   Downloading notebook-5.6.0-py2.py3-none-any.whl (8.9 MB)
#      |████████████████████████████████| 8.9 MB 24.7 MB/s
# Collecting numba==0.53.1
#   Downloading numba-0.53.1-cp37-cp37m-manylinux2014_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 38.9 MB/s
# Collecting numexpr==2.6.9
#   Downloading numexpr-2.6.9-cp37-cp37m-manylinux1_x86_64.whl (163 kB)
#      |████████████████████████████████| 163 kB 23.0 MB/s
# Collecting numpy==1.17.4
#   Downloading numpy-1.17.4-cp37-cp37m-manylinux1_x86_64.whl (20.0 MB)
#      |████████████████████████████████| 20.0 MB 1.4 MB/s
# Collecting numpydoc==0.8.0
#   Downloading numpydoc-0.8.0.tar.gz (20 kB)
# Collecting opencv-python==4.4.0.42
#   Downloading opencv_python-4.4.0.42-cp37-cp37m-manylinux2014_x86_64.whl (49.4 MB)
#      |████████████████████████████████| 49.4 MB 120 kB/s
# Collecting OpenMM==0.2
#   Downloading openmm-0.2.tar.gz (3.5 MB)
#      |████████████████████████████████| 3.5 MB 39.2 MB/s
# Collecting openslide-python==1.1.2
#   Downloading openslide-python-1.1.2.tar.gz (316 kB)
#      |████████████████████████████████| 316 kB 34.4 MB/s
# Collecting overrides==1.9
#   Downloading overrides-1.9.tar.gz (3.4 kB)
# Collecting packaging==17.1
#   Downloading packaging-17.1-py2.py3-none-any.whl (24 kB)
# Collecting pandas==1.0.5
#   Downloading pandas-1.0.5-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 35.6 MB/s
# Collecting pandocfilters==1.4.2
#   Downloading pandocfilters-1.4.2.tar.gz (14 kB)
# Collecting parsimonious==0.8.0
#   Downloading parsimonious-0.8.0.tar.gz (38 kB)
# Collecting parso==0.3.1
#   Downloading parso-0.3.1-py2.py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 6.3 MB/s
# Collecting partd==0.3.8
#   Downloading partd-0.3.8-py2.py3-none-any.whl (19 kB)
# Collecting pathos==0.2.2.1
#   Downloading pathos-0.2.2.1.tar.gz (161 kB)
#      |████████████████████████████████| 161 kB 39.8 MB/s
# Collecting patsy==0.5.1
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
#      |████████████████████████████████| 231 kB 58.5 MB/s
# Collecting pbr==5.1.1
#   Downloading pbr-5.1.1-py2.py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 55.9 MB/s
# Collecting pexpect==4.6.0
#   Downloading pexpect-4.6.0-py2.py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 3.5 MB/s
# Collecting pickleshare==0.7.4
#   Downloading pickleshare-0.7.4-py2.py3-none-any.whl (6.9 kB)
# Collecting Pillow==5.1.0
#   Downloading Pillow-5.1.0.tar.gz (14.3 MB)
#      |████████████████████████████████| 14.3 MB 25.6 MB/s
# Collecting plac==0.9.6
#   Downloading plac-0.9.6-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: pluggy==0.7.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 146)) (0.7.1)
# Collecting pomegranate==0.14.0
#   Downloading pomegranate-0.14.0-cp37-cp37m-manylinux2010_x86_64.whl (17.9 MB)
#      |████████████████████████████████| 17.9 MB 224 kB/s
# Collecting pox==0.2.4
#   Downloading pox-0.2.4.tar.gz (109 kB)
#      |████████████████████████████████| 109 kB 47.3 MB/s
# Collecting ppft==1.6.4.8
#   Downloading ppft-1.6.4.8.tar.gz (60 kB)
#      |████████████████████████████████| 60 kB 5.1 MB/s
# Collecting preshed==1.0.1
#   Downloading preshed-1.0.1-cp37-cp37m-manylinux1_x86_64.whl (79 kB)
#      |████████████████████████████████| 79 kB 5.7 MB/s
# Collecting prometheus-client==0.3.0
#   Downloading prometheus_client-0.3.0.tar.gz (22 kB)
# Collecting prompt-toolkit==1.0.15
#   Downloading prompt_toolkit-1.0.15-py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 50.2 MB/s
# Collecting protobuf==3.6.1
#   Downloading protobuf-3.6.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 28.3 MB/s
# Collecting prov==1.5.3
#   Downloading prov-1.5.3-py2.py3-none-any.whl (423 kB)
#      |████████████████████████████████| 423 kB 47.8 MB/s
# Collecting psutil==5.7.0
#   Downloading psutil-5.7.0.tar.gz (449 kB)
#      |████████████████████████████████| 449 kB 42.8 MB/s
# Collecting psycopg2==2.7.5
#   Downloading psycopg2-2.7.5-cp37-cp37m-manylinux1_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 36.4 MB/s
# Collecting ptyprocess==0.6.0
#   Downloading ptyprocess-0.6.0-py2.py3-none-any.whl (39 kB)
# Collecting py==1.5.4
#   Downloading py-1.5.4-py2.py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.5 MB/s
# Collecting pyaml==17.12.1
#   Downloading pyaml-17.12.1-py2.py3-none-any.whl (20 kB)
# Collecting pyasn1==0.4.4
#   Downloading pyasn1-0.4.4-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 849 kB/s
# Collecting pycparser==2.18
#   Downloading pycparser-2.18.tar.gz (245 kB)
#      |████████████████████████████████| 245 kB 63.5 MB/s
# Collecting pycryptodome==3.7.0
#   Downloading pycryptodome-3.7.0-cp37-cp37m-manylinux1_x86_64.whl (7.4 MB)
#      |████████████████████████████████| 7.4 MB 19.5 MB/s
# Collecting pycuda==2018.1.1
#   Downloading pycuda-2018.1.1.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 57.2 MB/s
# Collecting pydot==1.4.1
#   Downloading pydot-1.4.1-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: pydotplus==2.0.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 165)) (2.0.2)
# Collecting pyfaidx==0.5.9.2
#   Downloading pyfaidx-0.5.9.2.tar.gz (32 kB)
# Collecting Pygments==2.2.0
#   Downloading Pygments-2.2.0-py2.py3-none-any.whl (841 kB)
#      |████████████████████████████████| 841 kB 47.2 MB/s
# Collecting pyhocon==0.3.35
#   Downloading pyhocon-0.3.35.tar.gz (94 kB)
#      |████████████████████████████████| 94 kB 2.4 MB/s
# Collecting pynndescent==0.5.2
#   Downloading pynndescent-0.5.2.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 56.3 MB/s
# Collecting pyparsing==2.2.0
#   Downloading pyparsing-2.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 3.6 MB/s
# Collecting pysam==0.16.0.1
#   Downloading pysam-0.16.0.1-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 37.6 MB/s
# Collecting pytest==3.7.1
#   Downloading pytest-3.7.1-py2.py3-none-any.whl (202 kB)
#      |████████████████████████████████| 202 kB 39.3 MB/s
# Collecting python-dateutil==2.7.3
#   Downloading python_dateutil-2.7.3-py2.py3-none-any.whl (211 kB)
#      |████████████████████████████████| 211 kB 33.3 MB/s
# Collecting python-jose==2.0.2
#   Downloading python_jose-2.0.2-py2.py3-none-any.whl (21 kB)
# Collecting pytools==2019.1
#   Downloading pytools-2019.1.tar.gz (57 kB)
#      |████████████████████████████████| 57 kB 4.0 MB/s
# Collecting pytz==2017.3
#   Downloading pytz-2017.3-py2.py3-none-any.whl (511 kB)
#      |████████████████████████████████| 511 kB 45.2 MB/s
# Collecting PyWavelets==1.1.1
#   Downloading PyWavelets-1.1.1-cp37-cp37m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 43.4 MB/s
# Collecting PyYAML==3.12
#   Downloading PyYAML-3.12.zip (375 kB)
#      |████████████████████████████████| 375 kB 36.4 MB/s
# Collecting pyzmq==17.1.0
#   Downloading pyzmq-17.1.0-cp37-cp37m-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 59.4 MB/s
# Collecting qtconsole==4.3.1
#   Downloading qtconsole-4.3.1-py2.py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 69.4 MB/s
# Collecting rdflib==4.2.2
#   Downloading rdflib-4.2.2-py3-none-any.whl (344 kB)
#      |████████████████████████████████| 344 kB 65.4 MB/s
# Collecting regex==2017.4.5
#   Downloading regex-2017.04.05.tar.gz (601 kB)
#      |████████████████████████████████| 601 kB 41.7 MB/s
# Collecting reportlab==3.5.44
#   Downloading reportlab-3.5.44-cp37-cp37m-manylinux2010_x86_64.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 45.8 MB/s
# Collecting requests==2.19.1
#   Downloading requests-2.19.1-py2.py3-none-any.whl (91 kB)
#      |████████████████████████████████| 91 kB 7.1 MB/s
# Collecting responses==0.9.0
#   Downloading responses-0.9.0-py2.py3-none-any.whl (12 kB)
# Collecting rsa==3.4.2
#   Downloading rsa-3.4.2-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 3.2 MB/s
# Collecting s3transfer==0.1.13
#   Downloading s3transfer-0.1.13-py2.py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 5.8 MB/s
# Collecting sacremoses==0.0.38
#   Downloading sacremoses-0.0.38.tar.gz (860 kB)
#      |████████████████████████████████| 860 kB 54.7 MB/s
# Collecting scikit-cuda==0.5.2
#   Downloading scikit_cuda-0.5.2-py2.py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 46.9 MB/s
# Collecting scikit-image==0.17.2
#   Downloading scikit_image-0.17.2-cp37-cp37m-manylinux1_x86_64.whl (12.5 MB)
#      |████████████████████████████████| 12.5 MB 45.4 MB/s
# Collecting scikit-learn==0.23.1
#   Downloading scikit_learn-0.23.1-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 32.6 MB/s
# Collecting scikit-optimize==0.5.2
#   Downloading scikit_optimize-0.5.2-py2.py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 1.1 MB/s
# Collecting scikit-plot==0.3.7
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting scipy==1.5.4
#   Downloading scipy-1.5.4-cp37-cp37m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 2.0 MB/s
# Collecting seaborn==0.9.0
#   Downloading seaborn-0.9.0-py3-none-any.whl (208 kB)
#      |████████████████████████████████| 208 kB 55.3 MB/s
# Collecting Send2Trash==1.5.0
#   Downloading Send2Trash-1.5.0-py3-none-any.whl (12 kB)
# Collecting sentencepiece==0.1.85
#   Downloading sentencepiece-0.1.85-cp37-cp37m-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 51.1 MB/s
# Collecting SigProfilerExtractor==1.0.12
#   Downloading SigProfilerExtractor-1.0.12-py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 38.9 MB/s
# Collecting SigProfilerMatrixGenerator==1.1.17
#   Downloading SigProfilerMatrixGenerator-1.1.17-py3-none-any.whl (36.2 MB)
#      |████████████████████████████████| 36.2 MB 1.2 MB/s
# Collecting sigProfilerPlotting==1.1.6
#   Downloading sigProfilerPlotting-1.1.6.tar.gz (2.6 MB)
#      |████████████████████████████████| 2.6 MB 43.6 MB/s
# Requirement already satisfied: simplegeneric==0.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 202)) (0.8.1)
# Collecting SimpleITK==1.2.0
#   Downloading SimpleITK-1.2.0-cp37-cp37m-manylinux1_x86_64.whl (42.5 MB)
#      |████████████████████████████████| 42.5 MB 1.4 MB/s
# Collecting simplejson==3.16.0
#   Downloading simplejson-3.16.0.tar.gz (81 kB)
#      |████████████████████████████████| 81 kB 685 kB/s
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 205)) (1.15.0)
# Requirement already satisfied: sklearn==0.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 206)) (0.0)
# Collecting snowballstemmer==1.2.1
#   Downloading snowballstemmer-1.2.1-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.1 MB/s
# Collecting sortedcontainers==2.0.5
#   Downloading sortedcontainers-2.0.5-py2.py3-none-any.whl (28 kB)
# Collecting spacy==2.0.12
#   Downloading spacy-2.0.12.tar.gz (22.0 MB)
#      |████████████████████████████████| 22.0 MB 9.2 MB/s
# Collecting spams==2.6.1
#   Downloading spams-2.6.1.tar.gz (1.9 MB)
#      |████████████████████████████████| 1.9 MB 43.8 MB/s
# Collecting spams-mkl==2.6.1
#   Downloading spams_mkl-2.6.1.tar.gz (1.9 MB)
#      |████████████████████████████████| 1.9 MB 47.7 MB/s
# Collecting Sphinx==1.7.6
#   Downloading Sphinx-1.7.6-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 51.3 MB/s
# Collecting sphinx-rtd-theme==0.4.3
#   Downloading sphinx_rtd_theme-0.4.3-py2.py3-none-any.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 34.9 MB/s
# Collecting sphinxcontrib-websupport==1.1.0
#   Downloading sphinxcontrib_websupport-1.1.0-py2.py3-none-any.whl (26 kB)
# Collecting sqlparse==0.2.4
#   Downloading sqlparse-0.2.4-py2.py3-none-any.whl (38 kB)
# Collecting stardist==0.7.2
#   Downloading stardist-0.7.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 40.9 MB/s
# Collecting statsmodels==0.11.1
#   Downloading statsmodels-0.11.1-cp37-cp37m-manylinux1_x86_64.whl (8.7 MB)
#      |████████████████████████████████| 8.7 MB 23.9 MB/s
# Collecting style==1.1.0
#   Downloading style-1.1.0-py2.py3-none-any.whl (6.4 kB)
# Requirement already satisfied: tables==3.4.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 219)) (3.4.4)
# Collecting tblib==1.3.2
#   Downloading tblib-1.3.2-py2.py3-none-any.whl (13 kB)
# Collecting tensorboard==1.9.0
#   Downloading tensorboard-1.9.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 39.3 MB/s
# Collecting tensorboardX==1.2
#   Downloading tensorboardX-1.2-py2.py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 2.2 MB/s
# Collecting tensorflow-gpu==2.0.0
#   Downloading tensorflow_gpu-2.0.0-cp37-cp37m-manylinux2010_x86_64.whl (380.8 MB)
#      |████████████████████████████████| 380.8 MB 32 kB/s
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 224)) (1.1.0)
# Collecting terminado==0.8.1
#   Downloading terminado-0.8.1-py2.py3-none-any.whl (33 kB)
# Collecting testpath==0.3.1
#   Downloading testpath-0.3.1-py2.py3-none-any.whl (161 kB)
#      |████████████████████████████████| 161 kB 52.7 MB/s
# Collecting Theano==1.0.4
#   Downloading Theano-1.0.4.tar.gz (2.8 MB)
#      |████████████████████████████████| 2.8 MB 37.4 MB/s
# Collecting thinc==6.10.3
#   Downloading thinc-6.10.3.tar.gz (1.2 MB)
#      |████████████████████████████████| 1.2 MB 60.8 MB/s
# Collecting threadpoolctl==2.1.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting tifffile==2020.6.3
#   Downloading tifffile-2020.6.3-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 62.1 MB/s
# Collecting tokenizers==0.0.11
#   Downloading tokenizers-0.0.11-cp37-cp37m-manylinux1_x86_64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 45.1 MB/s
# Collecting toolz==0.9.0
#   Downloading toolz-0.9.0.tar.gz (45 kB)
#      |████████████████████████████████| 45 kB 2.5 MB/s
# Collecting topaz==0.0.3
#   Downloading topaz-0.0.3-py3-none-any.whl (5.4 kB)
# Collecting topaz-em==0.2.2
#   Downloading topaz-em-0.2.2.tar.gz (14.5 MB)
#      |████████████████████████████████| 14.5 MB 20.7 MB/s
# Collecting torch==1.4.0
#   Downloading torch-1.4.0-cp37-cp37m-manylinux1_x86_64.whl (753.4 MB)
#      |████████████████████████████████| 753.4 MB 6.4 kB/s
# Collecting torchtext==0.2.3
#   Downloading torchtext-0.2.3.tar.gz (42 kB)
#      |████████████████████████████████| 42 kB 1.1 MB/s
# Collecting torchvision==0.5.0
#   Downloading torchvision-0.5.0-cp37-cp37m-manylinux1_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 36.7 MB/s
# Collecting tornado==5.1
#   Downloading tornado-5.1.tar.gz (516 kB)
#      |████████████████████████████████| 516 kB 36.9 MB/s
# Collecting tqdm==4.42.0
#   Downloading tqdm-4.42.0-py2.py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 4.7 MB/s
# Collecting traitlets==4.3.2
#   Downloading traitlets-4.3.2-py2.py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 2.2 MB/s
# Collecting traits==5.0.0
#   Downloading traits-5.0.0.tar.gz (437 kB)
#      |████████████████████████████████| 437 kB 54.1 MB/s
# Collecting transformers==2.4.1
#   Downloading transformers-2.4.1-py3-none-any.whl (475 kB)
#      |████████████████████████████████| 475 kB 50.5 MB/s
# Collecting typing==3.6.4
#   Downloading typing-3.6.4-py3-none-any.whl (22 kB)
# Collecting typing-extensions==3.7.4.2
#   Downloading typing_extensions-3.7.4.2-py3-none-any.whl (22 kB)
# Collecting ujson==1.35
#   Downloading ujson-1.35.tar.gz (192 kB)
#      |████████████████████████████████| 192 kB 58.5 MB/s
# Collecting umap==0.1.1
#   Downloading umap-0.1.1.tar.gz (3.2 kB)
# Collecting umap-learn==0.5.1
#   Downloading umap-learn-0.5.1.tar.gz (80 kB)
#      |████████████████████████████████| 80 kB 7.4 MB/s
# Collecting Unidecode==1.0.22
#   Downloading Unidecode-1.0.22-py2.py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 43.6 MB/s
# Collecting update==0.0.1
#   Downloading update-0.0.1-py2.py3-none-any.whl (2.9 kB)
# Collecting urllib3==1.23
#   Downloading urllib3-1.23-py2.py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 43.1 MB/s
# Collecting wcwidth==0.1.7
#   Downloading wcwidth-0.1.7-py2.py3-none-any.whl (21 kB)
# Collecting websocket-client==0.54.0
#   Downloading websocket_client-0.54.0-py2.py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 41.3 MB/s
# Collecting Werkzeug==0.14.1
#   Downloading Werkzeug-0.14.1-py2.py3-none-any.whl (322 kB)
#      |████████████████████████████████| 322 kB 37.4 MB/s
# Collecting widgetsnbextension==3.3.0
#   Downloading widgetsnbextension-3.3.0-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 41.5 MB/s
# Collecting wrapt==1.10.11
#   Downloading wrapt-1.10.11.tar.gz (27 kB)
# Collecting xgboost==0.81
#   Downloading xgboost-0.81-py2.py3-none-manylinux1_x86_64.whl (16.6 MB)
#      |████████████████████████████████| 16.6 MB 144 kB/s
# Collecting xlrd==1.2.0
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 53.4 MB/s
# Collecting xmltodict==0.11.0
#   Downloading xmltodict-0.11.0-py2.py3-none-any.whl (7.2 kB)
# Collecting zict==0.1.3
#   Downloading zict-0.1.3-py2.py3-none-any.whl (10 kB)
# INFO: pip is looking at multiple versions of alabaster to determine which version is compatible with other requirements. This could take a while.
# INFO: pip is looking at multiple versions of absl-py to determine which version is compatible with other requirements. This could take a while.
# ERROR: Cannot install -r requirements.txt (line 3) and torch==1.4.0 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     The user requested torch==1.4.0
#     allennlp 0.7.1 depends on torch<0.5.0 and >=0.4.1
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/user_guide/#fixing-conflicting-dependencies

# %%
#!pip install allennlp
# Out:
# Collecting allennlp
#   Downloading allennlp-2.8.0-py3-none-any.whl (738 kB)
#      |████████████████████████████████| 738 kB 24.9 MB/s
# Collecting jsonnet>=0.10.0
#   Downloading jsonnet-0.18.0.tar.gz (592 kB)
#      |████████████████████████████████| 592 kB 55.1 MB/s
# Collecting fairscale==0.4.0
#   Downloading fairscale-0.4.0.tar.gz (190 kB)
#      |████████████████████████████████| 190 kB 66.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.4.1)
# Collecting checklist==0.0.11
#   Downloading checklist-0.0.11.tar.gz (12.1 MB)
#      |████████████████████████████████| 12.1 MB 43.5 MB/s
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from allennlp) (8.12.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.0.1)
# Collecting huggingface-hub>=0.0.16
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 509 kB/s
# Collecting sqlitedict
#   Downloading sqlitedict-1.7.0.tar.gz (28 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 52.0 MB/s
# Requirement already satisfied: torchvision<0.12.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.11.1+cu111)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from allennlp) (3.1.0)
# Requirement already satisfied: spacy<3.2,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from allennlp) (2.2.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from allennlp) (3.2.5)
# Collecting filelock<3.4,>=3.3
#   Downloading filelock-3.3.2-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.3.4)
# Collecting datasets<2.0,>=1.2.1
#   Downloading datasets-1.17.0-py3-none-any.whl (306 kB)
#      |████████████████████████████████| 306 kB 69.5 MB/s
# Collecting base58
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting tensorboardX>=1.2
#   Downloading tensorboardX-2.4.1-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 65.2 MB/s
# Collecting wandb<0.13.0,>=0.10.0
#   Downloading wandb-0.12.9-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 50.9 MB/s
# Collecting cached-path<0.4.0,>=0.3.1
#   Downloading cached_path-0.3.4-py3-none-any.whl (26 kB)
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.1.0)
# Requirement already satisfied: requests>=2.18 in /usr/local/lib/python3.7/dist-packages (from allennlp) (2.23.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from allennlp) (3.6.4)
# Collecting transformers<4.13,>=4.1
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 51.4 MB/s
# Collecting overrides==3.1.0
#   Downloading overrides-3.1.0.tar.gz (11 kB)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.99)
# Requirement already satisfied: tqdm>=4.19 in /usr/local/lib/python3.7/dist-packages (from allennlp) (4.62.3)
# Requirement already satisfied: torch<1.11.0,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.10.0+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.19.5)
# Collecting munch>=2.5
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: jupyter>=1.0 in /usr/local/lib/python3.7/dist-packages (from checklist==0.0.11->allennlp) (1.0.0)
# Requirement already satisfied: ipywidgets>=7.5 in /usr/local/lib/python3.7/dist-packages (from checklist==0.0.11->allennlp) (7.6.5)
# Collecting patternfork-nosql
#   Downloading patternfork_nosql-3.6.tar.gz (22.3 MB)
#      |████████████████████████████████| 22.3 MB 1.3 MB/s
# Collecting iso-639
#   Downloading iso-639-0.4.5.tar.gz (167 kB)
#      |████████████████████████████████| 167 kB 65.1 MB/s
# Collecting boto3<2.0,>=1.0
#   Downloading boto3-1.20.26-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 58.8 MB/s
# Collecting huggingface-hub>=0.0.16
#   Downloading huggingface_hub-0.1.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 8.1 MB/s
# Collecting cached-path<0.4.0,>=0.3.1
#   Downloading cached_path-0.3.3-py3-none-any.whl (26 kB)
#   Downloading cached_path-0.3.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: google-cloud-storage<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from cached-path<0.4.0,>=0.3.1->allennlp) (1.18.1)
# Collecting botocore<1.24.0,>=1.23.26
#   Downloading botocore-1.23.26-py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 43.1 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 8.7 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.24.0,>=1.23.26->boto3<2.0,>=1.0->cached-path<0.4.0,>=0.3.1->allennlp) (2.8.2)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 62.1 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets<2.0,>=1.2.1->allennlp) (1.1.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets<2.0,>=1.2.1->allennlp) (21.3)
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 57.6 MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets<2.0,>=1.2.1->allennlp) (0.70.12.2)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 37.0 MB/s
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets<2.0,>=1.2.1->allennlp) (3.0.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets<2.0,>=1.2.1->allennlp) (4.8.2)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2021.11.1-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 59.0 MB/s
# Requirement already satisfied: google-auth>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<2.0,>=1.0->cached-path<0.4.0,>=0.3.1->allennlp) (1.35.0)
# Requirement already satisfied: google-resumable-media<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<2.0,>=1.0->cached-path<0.4.0,>=0.3.1->allennlp) (0.4.1)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<2.0,>=1.0->cached-path<0.4.0,>=0.3.1->allennlp) (1.0.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage<2.0,>=1.0->cached-path<0.4.0,>=0.3.1->allennlp) (57.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage<2.0,>=1.0->cached-path<0.4.0,>=0.3.1->allennlp) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage<2.0,>=1.0->cached-path<0.4.0,>=0.3.1->allennlp) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage<2.0,>=1.0->cached-path<0.4.0,>=0.3.1->allennlp) (4.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage<2.0,>=1.0->cached-path<0.4.0,>=0.3.1->allennlp) (1.15.0)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage<2.0,>=1.0->cached-path<0.4.0,>=0.3.1->allennlp) (1.26.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage<2.0,>=1.0->cached-path<0.4.0,>=0.3.1->allennlp) (1.53.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage<2.0,>=1.0->cached-path<0.4.0,>=0.3.1->allennlp) (3.17.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage<2.0,>=1.0->cached-path<0.4.0,>=0.3.1->allennlp) (2018.9)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp) (3.13)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp) (3.10.0.2)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.5->checklist==0.0.11->allennlp) (5.5.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.5->checklist==0.0.11->allennlp) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.5->checklist==0.0.11->allennlp) (5.1.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.5->checklist==0.0.11->allennlp) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.5->checklist==0.0.11->allennlp) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.5->checklist==0.0.11->allennlp) (1.0.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.5->checklist==0.0.11->allennlp) (4.10.1)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist==0.0.11->allennlp) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist==0.0.11->allennlp) (5.3.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist==0.0.11->allennlp) (0.8.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist==0.0.11->allennlp) (1.0.18)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist==0.0.11->allennlp) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist==0.0.11->allennlp) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist==0.0.11->allennlp) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5->checklist==0.0.11->allennlp) (2.6.1)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.7/dist-packages (from jupyter>=1.0->checklist==0.0.11->allennlp) (5.2.1)
# Requirement already satisfied: notebook in /usr/local/lib/python3.7/dist-packages (from jupyter>=1.0->checklist==0.0.11->allennlp) (5.3.1)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.7/dist-packages (from jupyter>=1.0->checklist==0.0.11->allennlp) (5.2.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from jupyter>=1.0->checklist==0.0.11->allennlp) (5.6.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.5->checklist==0.0.11->allennlp) (2.6.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.5->checklist==0.0.11->allennlp) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets<2.0,>=1.2.1->allennlp) (3.0.6)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets>=7.5->checklist==0.0.11->allennlp) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2.0->google-cloud-storage<2.0,>=1.0->cached-path<0.4.0,>=0.3.1->allennlp) (0.4.8)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 56.7 MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18->allennlp) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18->allennlp) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18->allennlp) (2.10)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2,>=2.1.0->allennlp) (7.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2,>=2.1.0->allennlp) (2.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2,>=2.1.0->allennlp) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2,>=2.1.0->allennlp) (1.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2,>=2.1.0->allennlp) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2,>=2.1.0->allennlp) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2,>=2.1.0->allennlp) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2,>=2.1.0->allennlp) (0.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.2,>=2.1.0->allennlp) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets<2.0,>=1.2.1->allennlp) (3.6.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision<0.12.0,>=0.8.1->allennlp) (7.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<4.13,>=4.1->allennlp) (2019.12.20)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 57.2 MB/s
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 51.0 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 45.1 MB/s
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (2.3)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.24-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 58.6 MB/s
# Collecting subprocess32>=3.5.3
#   Downloading subprocess32-3.5.4.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 7.9 MB/s
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (7.1.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (5.4.8)
# Collecting configparser>=3.8.1
#   Downloading configparser-5.2.0-py3-none-any.whl (19 kB)
# Collecting yaspin>=1.0.0
#   Downloading yaspin-2.1.0-py3-none-any.whl (18 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.1-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 59.7 MB/s
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook->jupyter>=1.0->checklist==0.0.11->allennlp) (2.11.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook->jupyter>=1.0->checklist==0.0.11->allennlp) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook->jupyter>=1.0->checklist==0.0.11->allennlp) (0.12.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.5->checklist==0.0.11->allennlp) (22.3.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook->jupyter>=1.0->checklist==0.0.11->allennlp) (0.7.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets<2.0,>=1.2.1->allennlp) (21.2.0)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets<2.0,>=1.2.1->allennlp) (2.0.8)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 52.0 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (192 kB)
#      |████████████████████████████████| 192 kB 61.4 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 46.8 MB/s
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->allennlp) (1.5.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook->jupyter>=1.0->checklist==0.0.11->allennlp) (2.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter>=1.0->checklist==0.0.11->allennlp) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter>=1.0->checklist==0.0.11->allennlp) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter>=1.0->checklist==0.0.11->allennlp) (0.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter>=1.0->checklist==0.0.11->allennlp) (0.7.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter>=1.0->checklist==0.0.11->allennlp) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter>=1.0->checklist==0.0.11->allennlp) (0.8.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->jupyter>=1.0->checklist==0.0.11->allennlp) (0.5.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from patternfork-nosql->checklist==0.0.11->allennlp) (0.16.0)
# Collecting backports.csv
#   Downloading backports.csv-1.0.7-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from patternfork-nosql->checklist==0.0.11->allennlp) (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from patternfork-nosql->checklist==0.0.11->allennlp) (4.2.6)
# Collecting feedparser
#   Downloading feedparser-6.0.8-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 10.7 MB/s
# Collecting pdfminer.six
#   Downloading pdfminer.six-20211012-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 54.6 MB/s
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 48.3 MB/s
# Collecting cherrypy
#   Downloading CherryPy-18.6.1-py2.py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 36.8 MB/s
# Collecting portend>=2.1.1
#   Downloading portend-3.1.0-py3-none-any.whl (5.3 kB)
# Collecting jaraco.collections
#   Downloading jaraco.collections-3.4.0-py3-none-any.whl (10 kB)
# Collecting cheroot>=8.2.1
#   Downloading cheroot-8.5.2-py2.py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 7.3 MB/s
# Collecting zc.lockfile
#   Downloading zc.lockfile-2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting jaraco.functools
#   Downloading jaraco.functools-3.5.0-py3-none-any.whl (7.0 kB)
# Collecting tempora>=1.8
#   Downloading tempora-4.1.2-py3-none-any.whl (15 kB)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Collecting jaraco.text
#   Downloading jaraco.text-3.6.0-py3-none-any.whl (8.1 kB)
# Collecting jaraco.classes
#   Downloading jaraco.classes-3.2.1-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from jaraco.text->jaraco.collections->cherrypy->patternfork-nosql->checklist==0.0.11->allennlp) (5.4.0)
# Collecting cryptography
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 61.1 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography->pdfminer.six->patternfork-nosql->checklist==0.0.11->allennlp) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography->pdfminer.six->patternfork-nosql->checklist==0.0.11->allennlp) (2.21)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp) (1.11.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp) (1.4.0)
# Requirement already satisfied: qtpy in /usr/local/lib/python3.7/dist-packages (from qtconsole->jupyter>=1.0->checklist==0.0.11->allennlp) (1.11.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<4.13,>=4.1->allennlp) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->allennlp) (3.0.0)
# Building wheels for collected packages: checklist, fairscale, overrides, jsonnet, subprocess32, iso-639, pathtools, patternfork-nosql, python-docx, sgmllib3k, sqlitedict
#   Building wheel for checklist (setup.py) ... done
#   Created wheel for checklist: filename=checklist-0.0.11-py3-none-any.whl size=12165633 sha256=491749ab5ebf7e0b20886c0104736c310b728f3b19b69859cbf15de50d5b1c35
#   Stored in directory: /root/.cache/pip/wheels/6a/8a/07/6446879be434879c27671c83443727d74cecf6b630c8a24d03
#   Building wheel for fairscale (PEP 517) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.0-py3-none-any.whl size=239949 sha256=e5a771f21ff3184a7c0a8eafc1b5652284f9f720ee5012a7fa784f99ea4874b3
#   Stored in directory: /root/.cache/pip/wheels/28/8e/a3/7a2f33ac996114b816d88e55cf1235a1e058f30211e39bd719
#   Building wheel for overrides (setup.py) ... done
#   Created wheel for overrides: filename=overrides-3.1.0-py3-none-any.whl size=10186 sha256=2d528bda42390bf727788f6e38631a1d561cbd33ff77bdb40778e863e3e0cc65
#   Stored in directory: /root/.cache/pip/wheels/3a/0d/38/01a9bc6e20dcfaf0a6a7b552d03137558ba1c38aea47644682
#   Building wheel for jsonnet (setup.py) ... done
#   Created wheel for jsonnet: filename=jsonnet-0.18.0-cp37-cp37m-linux_x86_64.whl size=3994591 sha256=9537672431cf1b7c29ae7d2fa51efcee91e8b6b57a9914d4e486c79984f385dc
#   Stored in directory: /root/.cache/pip/wheels/a9/63/f9/a653f9c21575e6ff271ee6a49939aa002005174cea6c35919d
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=8fe6b5eec4518ff97f190879a26c618f7e94ad89edbbc546eb55799ab3eb6cbd
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
#   Building wheel for iso-639 (setup.py) ... done
#   Created wheel for iso-639: filename=iso_639-0.4.5-py3-none-any.whl size=169061 sha256=0b87aa55ca921082598098d45c52868b2d0c67c5dc385a2c15f8746ae86870d7
#   Stored in directory: /root/.cache/pip/wheels/47/60/19/6d020fc92138ed1b113a18271e83ea4b5525fe770cb45b9a2e
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=7fec3b69e48ed350a3dfebbde4f9caa5d1dac16b6eddcecb58054a4c6e74408e
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
#   Building wheel for patternfork-nosql (setup.py) ... done
#   Created wheel for patternfork-nosql: filename=patternfork_nosql-3.6-py3-none-any.whl size=22332806 sha256=d471347ce13b24bd85fe20c14a98270a3ad335975a512ddb03e44979d29d71e7
#   Stored in directory: /root/.cache/pip/wheels/97/72/8f/5305fe28168f93b658da9ed433b9a1d3ec90594faa0c9aaf4b
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184508 sha256=19bb0c222573627fffcb2455f8c01720f0f9338402c97260f38faeafdb83ac75
#   Stored in directory: /root/.cache/pip/wheels/f6/6f/b9/d798122a8b55b74ad30b5f52b01482169b445fbb84a11797a6
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6065 sha256=726d9742cfcfe4bd8d2a1503da4e687c3bdb03e07f0f177338e3595d006d8d49
#   Stored in directory: /root/.cache/pip/wheels/73/ad/a4/0dff4a6ef231fc0dfa12ffbac2a36cebfdddfe059f50e019aa
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-1.7.0-py3-none-any.whl size=14392 sha256=676d38d71ac44fefcd8eed1da7ba84b239b83fdd4dcf042302729c32610fc014
#   Stored in directory: /root/.cache/pip/wheels/af/94/06/18c0e83e9e227da8f3582810b51f319bbfd181e508676a56c8
# Successfully built checklist fairscale overrides jsonnet subprocess32 iso-639 pathtools patternfork-nosql python-docx sgmllib3k sqlitedict
# Installing collected packages: urllib3, jaraco.functools, tempora, multidict, jmespath, jaraco.text, jaraco.classes, frozenlist, zc.lockfile, yarl, smmap, sgmllib3k, pyyaml, portend, jaraco.collections, filelock, cryptography, cheroot, botocore, asynctest, async-timeout, aiosignal, tokenizers, sacremoses, s3transfer, python-docx, pdfminer.six, huggingface-hub, gitdb, fsspec, feedparser, cherrypy, backports.csv, aiohttp, yaspin, xxhash, transformers, subprocess32, shortuuid, sentry-sdk, patternfork-nosql, pathtools, overrides, munch, iso-639, GitPython, docker-pycreds, configparser, boto3, wandb, tensorboardX, sqlitedict, sentencepiece, jsonnet, fairscale, datasets, checklist, cached-path, base58, allennlp
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.4.0
#     Uninstalling filelock-3.4.0:
#       Successfully uninstalled filelock-3.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed GitPython-3.1.24 aiohttp-3.8.1 aiosignal-1.2.0 allennlp-2.8.0 async-timeout-4.0.2 asynctest-0.13.0 backports.csv-1.0.7 base58-2.1.1 boto3-1.20.26 botocore-1.23.26 cached-path-0.3.2 checklist-0.0.11 cheroot-8.5.2 cherrypy-18.6.1 configparser-5.2.0 cryptography-36.0.1 datasets-1.17.0 docker-pycreds-0.4.0 fairscale-0.4.0 feedparser-6.0.8 filelock-3.3.2 frozenlist-1.2.0 fsspec-2021.11.1 gitdb-4.0.9 huggingface-hub-0.1.2 iso-639-0.4.5 jaraco.classes-3.2.1 jaraco.collections-3.4.0 jaraco.functools-3.5.0 jaraco.text-3.6.0 jmespath-0.10.0 jsonnet-0.18.0 multidict-5.2.0 munch-2.5.0 overrides-3.1.0 pathtools-0.1.2 patternfork-nosql-3.6 pdfminer.six-20211012 portend-3.1.0 python-docx-0.8.11 pyyaml-6.0 s3transfer-0.5.0 sacremoses-0.0.46 sentencepiece-0.1.96 sentry-sdk-1.5.1 sgmllib3k-1.0.0 shortuuid-1.0.8 smmap-5.0.0 sqlitedict-1.7.0 subprocess32-3.5.4 tempora-4.1.2 tensorboardX-2.4.1 tokenizers-0.10.3 transformers-4.12.5 urllib3-1.25.11 wandb-0.12.9 xxhash-2.0.2 yarl-1.7.2 yaspin-2.1.0 zc.lockfile-2.0

# %%
# !cp requirements.txt /content/drive/MyDrive/GDC

# %%
# !apt-get install openslide-tools
# !apt-get install python-openslide
# !pip install openslide-python
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libopenslide0
# Suggested packages:
#   libtiff-tools
# The following NEW packages will be installed:
#   libopenslide0 openslide-tools
# 0 upgraded, 2 newly installed, 0 to remove and 37 not upgraded.
# Need to get 92.5 kB of archives.
# After this operation, 268 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenslide0 amd64 3.4.1+dfsg-2 [79.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 openslide-tools amd64 3.4.1+dfsg-2 [12.7 kB]
# Fetched 92.5 kB in 1s (180 kB/s)
# Selecting previously unselected package libopenslide0.
# (Reading database ... 155225 files and directories currently installed.)
# Preparing to unpack .../libopenslide0_3.4.1+dfsg-2_amd64.deb ...
# Unpacking libopenslide0 (3.4.1+dfsg-2) ...
# Selecting previously unselected package openslide-tools.
# Preparing to unpack .../openslide-tools_3.4.1+dfsg-2_amd64.deb ...
# Unpacking openslide-tools (3.4.1+dfsg-2) ...
# Setting up libopenslide0 (3.4.1+dfsg-2) ...
# Setting up openslide-tools (3.4.1+dfsg-2) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   javascript-common libjs-jquery python-asn1crypto python-blinker
#   python-cffi-backend python-click python-colorama python-cryptography
#   python-enum34 python-flask python-idna python-ipaddress python-itsdangerous
#   python-jinja2 python-markupsafe python-olefile python-openslide-examples
#   python-openssl python-pil python-pkg-resources python-pyinotify
#   python-simplejson python-six python-werkzeug
# Suggested packages:
#   apache2 | lighttpd | httpd python-blinker-doc python-cryptography-doc
#   python-cryptography-vectors python-enum34-doc python-flask-doc
#   python-jinja2-doc python-openssl-doc python-openssl-dbg python-pil-doc
#   python-pil-dbg python-setuptools python-pyinotify-doc ipython python-genshi
#   python-lxml python-greenlet python-redis python-pylibmc | python-memcache
#   python-termcolor python-watchdog python-werkzeug-doc
# The following NEW packages will be installed:
#   javascript-common libjs-jquery python-asn1crypto python-blinker
#   python-cffi-backend python-click python-colorama python-cryptography
#   python-enum34 python-flask python-idna python-ipaddress python-itsdangerous
#   python-jinja2 python-markupsafe python-olefile python-openslide
#   python-openslide-examples python-openssl python-pil python-pkg-resources
#   python-pyinotify python-simplejson python-six python-werkzeug
# 0 upgraded, 25 newly installed, 0 to remove and 37 not upgraded.
# Need to get 1,889 kB of archives.
# After this operation, 9,652 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-asn1crypto all 0.24.0-1 [72.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-blinker all 1.4+dfsg1-0.1 [13.0 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-cffi-backend amd64 1.11.5-1 [63.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-colorama all 0.3.7-1 [22.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-click all 6.7-3 [56.4 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-enum34 all 1.1.6-2 [34.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-idna all 2.6-1 [32.4 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-ipaddress all 1.0.17-1 [18.2 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-six all 1.11.0-2 [11.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-cryptography amd64 2.1.4-1ubuntu1.4 [276 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-itsdangerous all 0.24+dfsg1-2 [11.9 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-markupsafe amd64 1.0-1build1 [13.0 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-jinja2 all 2.10-1ubuntu0.18.04.1 [94.8 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-werkzeug all 0.14.1+dfsg1-1ubuntu0.1 [174 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-flask all 0.12.2-3ubuntu0.1 [62.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-olefile all 0.45.1-1 [33.2 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-pil amd64 5.1.0-1ubuntu0.6 [302 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-openslide amd64 1.1.1-2ubuntu4 [16.3 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-openslide-examples all 1.1.1-2ubuntu4 [168 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-openssl all 17.5.0-1ubuntu1 [41.3 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pkg-resources all 39.0.1-2 [128 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pyinotify all 0.9.6-1 [24.6 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-simplejson amd64 3.13.2-1 [61.2 kB]
# Fetched 1,889 kB in 1s (1,957 kB/s)
# Selecting previously unselected package javascript-common.
# (Reading database ... 155240 files and directories currently installed.)
# Preparing to unpack .../00-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../01-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package python-asn1crypto.
# Preparing to unpack .../02-python-asn1crypto_0.24.0-1_all.deb ...
# Unpacking python-asn1crypto (0.24.0-1) ...
# Selecting previously unselected package python-blinker.
# Preparing to unpack .../03-python-blinker_1.4+dfsg1-0.1_all.deb ...
# Unpacking python-blinker (1.4+dfsg1-0.1) ...
# Selecting previously unselected package python-cffi-backend.
# Preparing to unpack .../04-python-cffi-backend_1.11.5-1_amd64.deb ...
# Unpacking python-cffi-backend (1.11.5-1) ...
# Selecting previously unselected package python-colorama.
# Preparing to unpack .../05-python-colorama_0.3.7-1_all.deb ...
# Unpacking python-colorama (0.3.7-1) ...
# Selecting previously unselected package python-click.
# Preparing to unpack .../06-python-click_6.7-3_all.deb ...
# Unpacking python-click (6.7-3) ...
# Selecting previously unselected package python-enum34.
# Preparing to unpack .../07-python-enum34_1.1.6-2_all.deb ...
# Unpacking python-enum34 (1.1.6-2) ...
# Selecting previously unselected package python-idna.
# Preparing to unpack .../08-python-idna_2.6-1_all.deb ...
# Unpacking python-idna (2.6-1) ...
# Selecting previously unselected package python-ipaddress.
# Preparing to unpack .../09-python-ipaddress_1.0.17-1_all.deb ...
# Unpacking python-ipaddress (1.0.17-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../10-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-cryptography.
# Preparing to unpack .../11-python-cryptography_2.1.4-1ubuntu1.4_amd64.deb ...
# Unpacking python-cryptography (2.1.4-1ubuntu1.4) ...
# Selecting previously unselected package python-itsdangerous.
# Preparing to unpack .../12-python-itsdangerous_0.24+dfsg1-2_all.deb ...
# Unpacking python-itsdangerous (0.24+dfsg1-2) ...
# Selecting previously unselected package python-markupsafe.
# Preparing to unpack .../13-python-markupsafe_1.0-1build1_amd64.deb ...
# Unpacking python-markupsafe (1.0-1build1) ...
# Selecting previously unselected package python-jinja2.
# Preparing to unpack .../14-python-jinja2_2.10-1ubuntu0.18.04.1_all.deb ...
# Unpacking python-jinja2 (2.10-1ubuntu0.18.04.1) ...
# Selecting previously unselected package python-werkzeug.
# Preparing to unpack .../15-python-werkzeug_0.14.1+dfsg1-1ubuntu0.1_all.deb ...
# Unpacking python-werkzeug (0.14.1+dfsg1-1ubuntu0.1) ...
# Selecting previously unselected package python-flask.
# Preparing to unpack .../16-python-flask_0.12.2-3ubuntu0.1_all.deb ...
# Unpacking python-flask (0.12.2-3ubuntu0.1) ...
# Selecting previously unselected package python-olefile.
# Preparing to unpack .../17-python-olefile_0.45.1-1_all.deb ...
# Unpacking python-olefile (0.45.1-1) ...
# Selecting previously unselected package python-pil:amd64.
# Preparing to unpack .../18-python-pil_5.1.0-1ubuntu0.6_amd64.deb ...
# Unpacking python-pil:amd64 (5.1.0-1ubuntu0.6) ...
# Selecting previously unselected package python-openslide.
# Preparing to unpack .../19-python-openslide_1.1.1-2ubuntu4_amd64.deb ...
# Unpacking python-openslide (1.1.1-2ubuntu4) ...
# Selecting previously unselected package python-openslide-examples.
# Preparing to unpack .../20-python-openslide-examples_1.1.1-2ubuntu4_all.deb ...
# Unpacking python-openslide-examples (1.1.1-2ubuntu4) ...
# Selecting previously unselected package python-openssl.
# Preparing to unpack .../21-python-openssl_17.5.0-1ubuntu1_all.deb ...
# Unpacking python-openssl (17.5.0-1ubuntu1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../22-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-pyinotify.
# Preparing to unpack .../23-python-pyinotify_0.9.6-1_all.deb ...
# Unpacking python-pyinotify (0.9.6-1) ...
# Selecting previously unselected package python-simplejson.
# Preparing to unpack .../24-python-simplejson_3.13.2-1_amd64.deb ...
# Unpacking python-simplejson (3.13.2-1) ...
# Setting up python-idna (2.6-1) ...
# Setting up python-simplejson (3.13.2-1) ...
# Setting up libjs-jquery (3.2.1-1) ...
# Setting up python-asn1crypto (0.24.0-1) ...
# Setting up python-blinker (1.4+dfsg1-0.1) ...
# Setting up python-colorama (0.3.7-1) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up python-markupsafe (1.0-1build1) ...
# Setting up python-werkzeug (0.14.1+dfsg1-1ubuntu0.1) ...
# Setting up python-pyinotify (0.9.6-1) ...
# Setting up python-cffi-backend (1.11.5-1) ...
# Setting up python-six (1.11.0-2) ...
# Setting up python-enum34 (1.1.6-2) ...
# Setting up python-olefile (0.45.1-1) ...
# Setting up javascript-common (11) ...
# Setting up python-itsdangerous (0.24+dfsg1-2) ...
# Setting up python-ipaddress (1.0.17-1) ...
# Setting up python-pil:amd64 (5.1.0-1ubuntu0.6) ...
# Setting up python-jinja2 (2.10-1ubuntu0.18.04.1) ...
# Setting up python-click (6.7-3) ...
# Setting up python-openslide (1.1.1-2ubuntu4) ...
# Setting up python-cryptography (2.1.4-1ubuntu1.4) ...
# Setting up python-flask (0.12.2-3ubuntu0.1) ...
# Setting up python-openssl (17.5.0-1ubuntu1) ...
# Setting up python-openslide-examples (1.1.1-2ubuntu4) ...
# Collecting openslide-python
#   Using cached openslide-python-1.1.2.tar.gz (316 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from openslide-python) (7.1.2)
# Building wheels for collected packages: openslide-python
#   Building wheel for openslide-python (setup.py) ... done
#   Created wheel for openslide-python: filename=openslide_python-1.1.2-cp37-cp37m-linux_x86_64.whl size=27704 sha256=8aba3a559814e7a2c0bd91928d111df276a69343dfd64122d36cbbfd86cdd604
#   Stored in directory: /root/.cache/pip/wheels/6f/c3/97/980962653f9305314bfb6d93f80be5e21f13e206af66fc7ad3
# Successfully built openslide-python
# Installing collected packages: openslide-python
# Successfully installed openslide-python-1.1.2

# %%
# !pip install dicom
# Out:
# Collecting dicom
#   Using cached dicom-0.9.9.post1-py3-none-any.whl (766 kB)
# Installing collected packages: dicom
# Successfully installed dicom-0.9.9.post1

# %%
from __future__ import print_function
import json
import openslide
from openslide import open_slide, ImageSlide
from openslide.deepzoom import DeepZoomGenerator
from optparse import OptionParser
import re
import shutil
from unicodedata import normalize
import numpy as np
import scipy.misc
import subprocess
from glob import glob
from multiprocessing import Process, JoinableQueue
import time
import os
import sys
import dicom
# from scipy.misc import imsave
from imageio import imwrite as imsave
# from scipy.misc import imread
from imageio import imread
# from scipy.misc import imresize

from xml.dom import minidom
from PIL import Image, ImageDraw, ImageCms
from skimage import color, io
# Out:
# /usr/local/lib/python3.7/dist-packages/dicom/__init__.py:53: UserWarning:
# This code is using an older version of pydicom, which is no longer
# maintained as of Jan 2017.  You can access the new pydicom features and API
# by installing `pydicom` from PyPI.
# See 'Transitioning to pydicom 1.x' section at pydicom.readthedocs.org
# for more information.
#
#   warnings.warn(msg)

# %%
Image.MAX_IMAGE_PIXELS = None
VIEWER_SLIDE_NAME = 'slide'


class TileWorker(Process):
    """A child process that generates and writes tiles."""

    def __init__(self, queue, slidepath, tile_size, overlap, limit_bounds,quality, _Bkg, _ROIpc):
        Process.__init__(self, name='TileWorker')
        self.daemon = True
        self._queue = queue
        self._slidepath = slidepath
        self._tile_size = tile_size
        self._overlap = overlap
        self._limit_bounds = limit_bounds
        self._quality = quality
        self._slide = None
        self._Bkg = _Bkg
        self._ROIpc = _ROIpc

    def RGB_to_lab(self, tile):
        # srgb_p = ImageCms.createProfile("sRGB")
        # lab_p  = ImageCms.createProfile("LAB")
        # rgb2lab = ImageCms.buildTransformFromOpenProfiles(srgb_p, lab_p, "RGB", "LAB")
        # Lab = ImageCms.applyTransform(tile, rgb2lab)
        # Lab = np.array(Lab)
        # Lab = Lab.astype('float')
        # Lab[:,:,0] = Lab[:,:,0] / 2.55
        # Lab[:,:,1] = Lab[:,:,1] - 128
        # Lab[:,:,2] = Lab[:,:,2] - 128
        print("RGB to Lab")
        Lab = color.rgb2lab(tile)
        return Lab

    def Lab_to_RGB(self,Lab):
        # srgb_p = ImageCms.createProfile("sRGB")
        # lab_p  = ImageCms.createProfile("LAB")
        # lab2rgb = ImageCms.buildTransformFromOpenProfiles(srgb_p, lab_p, "LAB", "RGB")
        # Lab[:,:,0] = Lab[:,:,0] * 2.55
        # Lab[:,:,1] = Lab[:,:,1] + 128
        # Lab[:,:,2] = Lab[:,:,2] + 128
        # newtile = ImageCms.applyTransform(Lab, lab2rgb)
        print("Lab to RGB")
        newtile = (color.lab2rgb(Lab) * 255).astype(np.uint8)
        return newtile


    def normalize_tile(self, tile, NormVec):
        Lab = self.RGB_to_lab(tile)
        TileMean = [0,0,0]
        TileStd = [1,1,1]
        newMean = NormVec[0:3] 
        newStd = NormVec[3:6]
        for i in range(3):
            TileMean[i] = np.mean(Lab[:,:,i])
            TileStd[i] = np.std(Lab[:,:,i])
            # print("mean/std chanel " + str(i) + ": " + str(TileMean[i]) + " / " + str(TileStd[i]))
            tmp = ((Lab[:,:,i] - TileMean[i]) * (newStd[i] / TileStd[i])) + newMean[i]
            if i == 0:
                tmp[tmp<0] = 0 
                tmp[tmp>100] = 100 
                Lab[:,:,i] = tmp
            else:
                tmp[tmp<-128] = 128 
                tmp[tmp>127] = 127 
                Lab[:,:,i] = tmp
        tile = self.Lab_to_RGB(Lab)
        return tile

    def run(self):
        self._slide = open_slide(self._slidepath)
        last_associated = None
        dz = self._get_dz()
        while True:
            data = self._queue.get()
            if data is None:
                self._queue.task_done()
                break
            #associated, level, address, outfile = data
            associated, level, address, outfile, format, outfile_bw, PercentMasked, SaveMasks, TileMask, Normalize = data
            if last_associated != associated:
                dz = self._get_dz(associated)
                last_associated = associated
            #try:
            if True:
                try:
                    tile = dz.get_tile(level, address)
                    # A single tile is being read
                    #check the percentage of the image with "information". Should be above 50%
                    gray = tile.convert('L')
                    bw = gray.point(lambda x: 0 if x<220 else 1, 'F')
                    arr = np.array(np.asarray(bw))
                    avgBkg = np.average(bw)
                    bw = gray.point(lambda x: 0 if x<220 else 1, '1')
                    # check if the image is mostly background
                    # print("res: " + outfile + " is " + str(avgBkg))
                    if avgBkg <= (self._Bkg / 100.0):
                        print("PercentMasked: %.6f, %.6f" % (PercentMasked, self._ROIpc / 100.0) )
                        # if an Aperio selection was made, check if is within the selected region
                        if PercentMasked >= (self._ROIpc / 100.0):

                            if Normalize != '':
                                # print("normalize " + str(outfile))
                                # arrtile = np.array(tile)
                                tile = Image.fromarray(self.normalize_tile(tile, Normalize).astype('uint8'),'RGB')

                            tile.save(outfile, quality=self._quality)
                            if bool(SaveMasks)==True:
                                height = TileMask.shape[0]
                                width = TileMask.shape[1]
                                TileMaskO = np.zeros((height,width,3), 'uint8')
                                maxVal = float(TileMask.max())
                                TileMaskO[...,0] = (TileMask[:,:].astype(float)  / maxVal * 255.0).astype(int)
                                TileMaskO[...,1] = (TileMask[:,:].astype(float)  / maxVal * 255.0).astype(int)
                                TileMaskO[...,2] = (TileMask[:,:].astype(float)  / maxVal * 255.0).astype(int)
                                TileMaskO = numpy.array(Image.fromarray(TileMaskO).resize(arr.shape[0], arr.shape[1],3))
                                # TileMaskO = imresize(TileMaskO, (arr.shape[0], arr.shape[1],3))
                                TileMaskO[TileMaskO<10] = 0
                                TileMaskO[TileMaskO>=10] = 255
                                imsave(outfile_bw,TileMaskO) #(outfile_bw, quality=self._quality)

                        #print("%s good: %f" %(outfile, avgBkg))
                    #elif level>5:
                    #    tile.save(outfile, quality=self._quality)
                            #print("%s empty: %f" %(outfile, avgBkg))
                    self._queue.task_done()
                except Exception as e:
                    # print(level, address)
                    print("image %s failed at dz.get_tile for level %f" % (self._slidepath, level))
                    # e = sys.exc_info()[0]
                    print(e)
                    self._queue.task_done()

    def _get_dz(self, associated=None):
        if associated is not None:
            image = ImageSlide(self._slide.associated_images[associated])
        else:
            image = self._slide
        return DeepZoomGenerator(image, self._tile_size, self._overlap, limit_bounds=self._limit_bounds)

# %%
class DeepZoomImageTiler(object):
    """Handles generation of tiles and metadata for a single image."""

    def __init__(self, dz, basename, format, associated, queue, slide, basenameJPG, xmlfile, mask_type, xmlLabel, ROIpc, ImgExtension, SaveMasks, Mag, normalize, Fieldxml):
        self._dz = dz
        self._basename = basename
        self._basenameJPG = basenameJPG
        self._format = format
        self._associated = associated
        self._queue = queue
        self._processed = 0
        self._slide = slide
        self._xmlfile = xmlfile
        self._mask_type = mask_type
        self._xmlLabel = xmlLabel
        self._ROIpc = ROIpc
        self._ImgExtension = ImgExtension
        self._SaveMasks = SaveMasks
        self._Mag = Mag
        self._normalize = normalize
        self._Fieldxml = Fieldxml

    def run(self):
        self._write_tiles()
        self._write_dzi()

    def _write_tiles(self):
            ########################################3
            # nc_added
        #level = self._dz.level_count-1
        Magnification = 20
        tol = 2
        #get slide dimensions, zoom levels, and objective information
        Factors = self._slide.level_downsamples
        try:
            Objective = float(self._slide.properties[openslide.PROPERTY_NAME_OBJECTIVE_POWER])
            # print(self._basename + " - Obj information found")
        except:
            print(self._basename + " - No Obj information found")
            print(self._ImgExtension)
            if ("jpg" in self._ImgExtension) | ("dcm" in self._ImgExtension) | ("tif" in self._ImgExtension):
                #Objective = self._ROIpc
                Objective = 1.
                Magnification = Objective
                print("input is jpg - will be tiled as such with %f" % Objective)
            else:
                return
        #calculate magnifications
        Available = tuple(Objective / x for x in Factors)
        #find highest magnification greater than or equal to 'Desired'
        Mismatch = tuple(x-Magnification for x in Available)
        AbsMismatch = tuple(abs(x) for x in Mismatch)
        if len(AbsMismatch) < 1:
          print(self._basename + " - Objective field empty!")
          return
        '''
        if(min(AbsMismatch) <= tol):
            Level = int(AbsMismatch.index(min(AbsMismatch)))
            Factor = 1
        else: #pick next highest level, downsample
            Level = int(max([i for (i, val) in enumerate(Mismatch) if val > 0]))
            Factor = Magnification / Available[Level]
        # end added
        '''
        xml_valid = False
        # a dir was provided for xml files

        '''
        ImgID = os.path.basename(self._basename)
        Nbr_of_masks = 0
        if self._xmlfile != '':
            xmldir = os.path.join(self._xmlfile, ImgID + '.xml')
            print("xml:")
            print(xmldir)
            if os.path.isfile(xmldir):
                xml_labels, xml_valid = self.xml_read_labels(xmldir)
                Nbr_of_masks = len(xml_labels)
            else:
                print("No xml file found for slide %s.svs (expected: %s). Directory or xml file does not exist" %  (ImgID, xmldir) )
                return
        else:
            Nbr_of_masks = 1
        '''

        if True:
            #if self._xmlfile != '' && :
            # print(self._xmlfile, self._ImgExtension)
            ImgID = os.path.basename(self._basename)
            xmldir = os.path.join(self._xmlfile, ImgID + '.xml')
            # print("xml:")
            # print(xmldir)
            if (self._xmlfile != '') & (self._ImgExtension != 'jpg') & (self._ImgExtension != 'dcm'):
                # print("read xml file...")
                mask, xml_valid, Img_Fact = self.xml_read(xmldir, self._xmlLabel, self._Fieldxml, self._ImgExtension)
                # if self._ImgExtension == 'scn':
                #   mask = mask.transpose()
                if xml_valid == False:
                    print("Error: xml %s file cannot be read properly - please check format" % xmldir)
                    return
            elif (self._xmlfile != '')  & (self._ImgExtension == 'dcm'):
                # print("check mask for dcm")
                mask, xml_valid, Img_Fact = self.jpg_mask_read(xmldir)
                # mask <-- read mask 
                #  Img_Fact <-- 1
                # xml_valid <-- True if mask file exists.
                if xml_valid == False:
                    print("Error: xml %s file cannot be read properly - please check format" % xmldir)
                    return

            # print("current directory: %s" % self._basename)

            #return
            #print(self._dz.level_count)

            for level in range(self._dz.level_count-1,-1,-1):
                ThisMag = Available[0]/pow(2,self._dz.level_count-(level+1))
                if self._Mag > 0:
                    if ThisMag != self._Mag:
                        continue
                ########################################
                #tiledir = os.path.join("%s_files" % self._basename, str(level))
                tiledir = os.path.join("%s_files" % self._basename, str(ThisMag))
                if not os.path.exists(tiledir):
                    os.makedirs(tiledir)
                cols, rows = self._dz.level_tiles[level]
                if xml_valid:
                    # print("xml valid")
                    '''# If xml file is used, check for each tile what are their corresponding coordinate in the base image
                    IndX_orig, IndY_orig = self._dz.level_tiles[-1]
                    CurrentLevel_ReductionFactor = (Img_Fact * float(self._dz.level_dimensions[-1][0]) / float(self._dz.level_dimensions[level][0]))
                    startIndX_current_level_conv = [int(i * CurrentLevel_ReductionFactor) for i in range(cols)]
                    print("***********")
                    endIndX_current_level_conv = [int(i * CurrentLevel_ReductionFactor) for i in range(cols)]
                    endIndX_current_level_conv.append(self._dz.level_dimensions[level][0])
                    endIndX_current_level_conv.pop(0)
    
                    startIndY_current_level_conv = [int(i * CurrentLevel_ReductionFactor) for i in range(rows)]
                    #endIndX_current_level_conv = [i * CurrentLevel_ReductionFactor - 1 for i in range(rows)]
                    endIndY_current_level_conv = [int(i * CurrentLevel_ReductionFactor) for i in range(rows)]
                    endIndY_current_level_conv.append(self._dz.level_dimensions[level][1])
                    endIndY_current_level_conv.pop(0)
                    '''
                    #startIndY_current_level_conv = []
                    #endIndY_current_level_conv = []
                    #startIndX_current_level_conv = []
                    #endIndX_current_level_conv = []

                    #for row in range(rows):
                    #    for col in range(cols):
                    #        Dlocation, Dlevel, Dsize = self._dz.get_tile_coordinates(level,(col, row))
                    #        Ddimension = self._dz.get_tile_dimensions(level,(col, row))
                    #        startIndY_current_level_conv.append(int((Dlocation[1]) / Img_Fact))
                    #        endIndY_current_level_conv.append(int((Dlocation[1] + Ddimension[1]) / Img_Fact))
                    #        startIndX_current_level_conv.append(int((Dlocation[0]) / Img_Fact))
                    #        endIndX_current_level_conv.append(int((Dlocation[0] + Ddimension[0]) / Img_Fact))
                            # print(Dlocation, Ddimension, int((Dlocation[1]) / Img_Fact), int((Dlocation[1] + Ddimension[1]) / Img_Fact), int((Dlocation[0]) / Img_Fact), int((Dlocation[0] + Ddimension[0]) / Img_Fact))
                for row in range(rows):
                    for col in range(cols):
                        InsertBaseName = False
                        if InsertBaseName:
                          tilename = os.path.join(tiledir, '%s_%d_%d.%s' % (
                                          self._basenameJPG, col, row, self._format))
                          tilename_bw = os.path.join(tiledir, '%s_%d_%d_mask.%s' % (
                                          self._basenameJPG, col, row, self._format))
                        else:
                          tilename = os.path.join(tiledir, '%d_%d.%s' % (
                                          col, row, self._format))
                          tilename_bw = os.path.join(tiledir, '%d_%d_mask.%s' % (
                                          col, row, self._format))
                        if xml_valid:
                            # compute percentage of tile in mask
                            # print(row, col)
                            # print(startIndX_current_level_conv[col])
                            # print(endIndX_current_level_conv[col])
                            # print(startIndY_current_level_conv[row])
                            # print(endIndY_current_level_conv[row])
                            # print(mask.shape)
                            # print(mask[startIndX_current_level_conv[col]:endIndX_current_level_conv[col], startIndY_current_level_conv[row]:endIndY_current_level_conv[row]])
                            # TileMask = mask[startIndY_current_level_conv[row]:endIndY_current_level_conv[row], startIndX_current_level_conv[col]:endIndX_current_level_conv[col]]
                            # PercentMasked = mask[startIndY_current_level_conv[row]:endIndY_current_level_conv[row], startIndX_current_level_conv[col]:endIndX_current_level_conv[col]].mean() 
                            # print(startIndY_current_level_conv[row], endIndY_current_level_conv[row], startIndX_current_level_conv[col], endIndX_current_level_conv[col])

                            Dlocation, Dlevel, Dsize = self._dz.get_tile_coordinates(level,(col, row))
                            Ddimension = tuple([pow(2,(self._dz.level_count - 1 - level)) * x for x in self._dz.get_tile_dimensions(level,(col, row))])
                            startIndY_current_level_conv = (int((Dlocation[1]) / Img_Fact))
                            endIndY_current_level_conv = (int((Dlocation[1] + Ddimension[1]) / Img_Fact))
                            startIndX_current_level_conv = (int((Dlocation[0]) / Img_Fact))
                            endIndX_current_level_conv = (int((Dlocation[0] + Ddimension[0]) / Img_Fact))


                            print(mask.shape, startIndY_current_level_conv, endIndY_current_level_conv, startIndX_current_level_conv, endIndX_current_level_conv)
                            if self._ImgExtension == 'scn':
                                startIndY_current_level_conv = int( ((Dlocation[1]) - self._dz.get_tile_coordinates(level,(0, 0))[0][1]) / Img_Fact)
                                endIndY_current_level_conv = int( ((Dlocation[1] + Ddimension[1])  - self._dz.get_tile_coordinates(level,(0, 0))[0][1]) / Img_Fact)
                                startIndX_current_level_conv = int( ((Dlocation[0]) - self._dz.get_tile_coordinates(level,(0, 0))[0][0]) / Img_Fact)
                                endIndX_current_level_conv = int( ((Dlocation[0] + Ddimension[0]) - self._dz.get_tile_coordinates(level,(0, 0))[0][0]) / Img_Fact)

                            print(Ddimension, Dlocation, Dlevel, Dsize, self._dz.level_count , level, col, row, Img_Fact)
                            print(mask.shape, startIndY_current_level_conv, endIndY_current_level_conv, startIndX_current_level_conv, endIndX_current_level_conv)
                            #startIndY_current_level_conv = (int((Dlocation[1]) / Img_Fact))
                            #endIndY_current_level_conv = (int((Dlocation[1] + Ddimension[1]) / Img_Fact))
                            #startIndX_current_level_conv = (int((Dlocation[0]) / Img_Fact))
                            #endIndX_current_level_conv = (int((Dlocation[0] + Ddimension[0]) / Img_Fact))
                            TileMask = mask[startIndY_current_level_conv:endIndY_current_level_conv, startIndX_current_level_conv:endIndX_current_level_conv]
                            PercentMasked = mask[startIndY_current_level_conv:endIndY_current_level_conv, startIndX_current_level_conv:endIndX_current_level_conv].mean() 

                            # print(Ddimension, startIndY_current_level_conv, endIndY_current_level_conv, startIndX_current_level_conv, endIndX_current_level_conv)


                            if self._mask_type == 0:
                                # keep ROI outside of the mask
                                PercentMasked = 1.0 - PercentMasked
                                # print("Invert Mask percentage")

                            # if PercentMasked > 0:
                            #     print("PercentMasked_p %.3f" % (PercentMasked))
                            # else:
                            #     print("PercentMasked_0 %.3f" % (PercentMasked))

 
                        else:
                            PercentMasked = 1.0
                            TileMask = []

                        if not os.path.exists(tilename):
                            self._queue.put((self._associated, level, (col, row),
                                        tilename, self._format, tilename_bw, PercentMasked, self._SaveMasks, TileMask, self._normalize))
                        self._tile_done()

    def _tile_done(self):
        self._processed += 1
        count, total = self._processed, self._dz.tile_count
        if count % 100 == 0 or count == total:
            print("Tiling %s: wrote %d/%d tiles" % (
                    self._associated or 'slide', count, total),
                    end='\r', file=sys.stderr)
            if count == total:
                print(file=sys.stderr)

    def _write_dzi(self):
        with open('%s.dzi' % self._basename, 'w') as fh:
            fh.write(self.get_dzi())

    def get_dzi(self):
        return self._dz.get_dzi(self._format)


    def jpg_mask_read(self, xmldir):
        # Original size of the image
        ImgMaxSizeX_orig = float(self._dz.level_dimensions[-1][0])
        ImgMaxSizeY_orig = float(self._dz.level_dimensions[-1][1])
        # Number of centers at the highest resolution
        cols, rows = self._dz.level_tiles[-1]
        # Img_Fact = int(ImgMaxSizeX_orig / 1.0 / cols)
        Img_Fact = 1
        try:
            # xmldir: change extension from xml to *jpg   
            xmldir = xmldir[:-4] + "mask.jpg"
            # xmlcontent = read xmldir image
            xmlcontent = imread(xmldir)
            xmlcontent = xmlcontent - np.min(xmlcontent)
            mask = xmlcontent / np.max(xmlcontent)
            # we want image between 0 and 1
            xml_valid = True
        except:
            xml_valid = False
            print("error with minidom.parse(xmldir)")
            return [], xml_valid, 1.0

        return mask, xml_valid, Img_Fact


    def xml_read(self, xmldir, Attribute_Name, Fieldxml, ImgExt):

        # Original size of the image
        ImgMaxSizeX_orig = float(self._dz.level_dimensions[-1][0])
        ImgMaxSizeY_orig = float(self._dz.level_dimensions[-1][1])
        # Number of centers at the highest resolution
        cols, rows = self._dz.level_tiles[-1]

        if ImgExt == 'scn':
            tmp = ImgMaxSizeX_orig
            ImgMaxSizeX_orig = ImgMaxSizeY_orig
            ImgMaxSizeY_orig = tmp


        NewFact = max(ImgMaxSizeX_orig, ImgMaxSizeY_orig) / min(max(ImgMaxSizeX_orig, ImgMaxSizeY_orig),15000.0)
        # Img_Fact = 
        # read_region(location, level, size)
        # dz.get_tile_coordinates(14,(0,2))
        # ((0, 1792), 1, (320, 384))

        Img_Fact = float(ImgMaxSizeX_orig) / 5.0 / float(cols)
       
        print("image info:")
        print(ImgMaxSizeX_orig, ImgMaxSizeY_orig, cols, rows) 
        try:
            xmlcontent = minidom.parse(xmldir)
            xml_valid = True
        except:
            xml_valid = False
            print("error with minidom.parse(xmldir)")
            return [], xml_valid, 1.0

        xy = {}
        xy_neg = {}
        NbRg = 0
        labelIDs = xmlcontent.getElementsByTagName('Annotation')
        # print("%d labels" % len(labelIDs) )
        for labelID in labelIDs:
            if (Attribute_Name==[]) | (Attribute_Name==''):
                    isLabelOK = True
            else:
                try:
                    labeltag = labelID.getElementsByTagName('Attribute')[0]
                    if (Attribute_Name==labeltag.attributes[Fieldxml].value):
                    # if (Attribute_Name==labeltag.attributes['Value'].value):
                    # if (Attribute_Name==labeltag.attributes['Name'].value):
                        isLabelOK = True
                    else:
                        isLabelOK = False
                except:
                	isLabelOK = False
            if Attribute_Name == "non_selected_regions":
                isLabelOK = True

            #print("label ID, tag:")
            #print(labelID, Attribute_Name, labeltag.attributes['Name'].value)
            #if Attribute_Name==labeltag.attributes['Name'].value:
            if isLabelOK:
                regionlist = labelID.getElementsByTagName('Region')
                for region in regionlist:
                    vertices = region.getElementsByTagName('Vertex')
                    NbRg += 1
                    regionID = region.attributes['Id'].value + str(NbRg)
                    NegativeROA = region.attributes['NegativeROA'].value
                    # print("%d vertices" % len(vertices))
                    if len(vertices) > 0:
                        #print( len(vertices) )
                        if NegativeROA=="0":
                            xy[regionID] = []
                            for vertex in vertices:
                                # get the x value of the vertex / convert them into index in the tiled matrix of the base image
                                # x = int(round(float(vertex.attributes['X'].value) / ImgMaxSizeX_orig * (cols*Img_Fact)))
                                # y = int(round(float(vertex.attributes['Y'].value) / ImgMaxSizeY_orig * (rows*Img_Fact)))
                                x = int(round(float(vertex.attributes['X'].value) / NewFact))
                                y = int(round(float(vertex.attributes['Y'].value) / NewFact))
                                xy[regionID].append((x,y))
                                #print(vertex.attributes['X'].value, vertex.attributes['Y'].value, x, y )
    
                        elif NegativeROA=="1":
                            xy_neg[regionID] = []
                            for vertex in vertices:
                                # get the x value of the vertex / convert them into index in the tiled matrix of the base image
                                # x = int(round(float(vertex.attributes['X'].value) / ImgMaxSizeX_orig * (cols*Img_Fact)))
                                # y = int(round(float(vertex.attributes['Y'].value) / ImgMaxSizeY_orig * (rows*Img_Fact)))
                                x = int(round(float(vertex.attributes['X'].value) / NewFact))
                                y = int(round(float(vertex.attributes['Y'].value) / NewFact))
                                xy_neg[regionID].append((x,y))
    

                        #xy_a = np.array(xy[regionID])

        # print("%d xy" % len(xy))
        #print(xy)
        # print("%d xy_neg"  % len(xy_neg))
        #print(xy_neg)
        print("NewFact:")
        print(NewFact)
        # img = Image.new('L', (int(cols*Img_Fact), int(rows*Img_Fact)), 0)
        img = Image.new('L', (int(ImgMaxSizeX_orig/NewFact), int(ImgMaxSizeY_orig/NewFact)), 0)
        for regionID in xy.keys():
            xy_a = xy[regionID]
            ImageDraw.Draw(img,'L').polygon(xy_a, outline=255, fill=255)
        for regionID in xy_neg.keys():
            xy_a = xy_neg[regionID]
            ImageDraw.Draw(img,'L').polygon(xy_a, outline=255, fill=0)
        #img = img.resize((cols,rows), Image.ANTIALIAS)
        mask = np.array(img)
        if ImgExt == 'scn':
                # mask = mask.transpose()
                mask = np.rot90(mask)   
        #print(mask.shape)
        if Attribute_Name == "non_selected_regions":
        	# scipy.misc.toimage(255-mask).save(os.path.join(os.path.split(self._basename[:-1])[0], "mask_" + os.path.basename(self._basename) + "_" + Attribute_Name + ".jpeg"))
                Image.fromarray(255-mask).save(os.path.join(os.path.split(self._basename[:-1])[0], "mask_" + os.path.basename(self._basename) + "_" + Attribute_Name + ".jpeg"))
        else:
           if self._mask_type==0:
               # scipy.misc.toimage(255-mask).save(os.path.join(os.path.split(self._basename[:-1])[0], "mask_" + os.path.basename(self._basename) + "_" + Attribute_Name + "_inv.jpeg"))
               Image.fromarray(255-mask).save(os.path.join(os.path.split(self._basename[:-1])[0], "mask_" + os.path.basename(self._basename) + "_" + Attribute_Name + "_inv.jpeg"))
           else:
               # scipy.misc.toimage(mask).save(os.path.join(os.path.split(self._basename[:-1])[0], "mask_" + os.path.basename(self._basename) + "_" + Attribute_Name + ".jpeg"))
               Image.fromarray(mask).save(os.path.join(os.path.split(self._basename[:-1])[0], "mask_" + os.path.basename(self._basename) + "_" + Attribute_Name + ".jpeg"))  
        #print(mask)
        return mask / 255.0, xml_valid, NewFact
        # Img_Fact

# %%
class DeepZoomStaticTiler(object):
    """Handles generation of tiles and metadata for all images in a slide."""

    def __init__(self, slidepath, basename, format, tile_size, overlap,
                limit_bounds, quality, workers, with_viewer, Bkg, basenameJPG, xmlfile, mask_type, ROIpc, oLabel, ImgExtension, SaveMasks, Mag, normalize, Fieldxml):
        if with_viewer:
            # Check extra dependency before doing a bunch of work
            import jinja2
        #print("line226 - %s " % (slidepath) )
        self._slide = open_slide(slidepath)
        self._basename = basename
        self._basenameJPG = basenameJPG
        self._xmlfile = xmlfile
        self._mask_type = mask_type
        self._format = format
        self._tile_size = tile_size
        self._overlap = overlap
        self._limit_bounds = limit_bounds
        self._queue = JoinableQueue(2 * workers)
        self._workers = workers
        self._with_viewer = with_viewer
        self._Bkg = Bkg
        self._ROIpc = ROIpc
        self._dzi_data = {}
        self._xmlLabel = oLabel
        self._ImgExtension = ImgExtension
        self._SaveMasks = SaveMasks
        self._Mag = Mag
        self._normalize = normalize
        self._Fieldxml = Fieldxml

        for _i in range(workers):
            TileWorker(self._queue, slidepath, tile_size, overlap,
                limit_bounds, quality, self._Bkg, self._ROIpc).start()

    def run(self):
        self._run_image()
        if self._with_viewer:
            for name in self._slide.associated_images:
                self._run_image(name)
            self._write_html()
            self._write_static()
        self._shutdown()

    def _run_image(self, associated=None):
        """Run a single image from self._slide."""
        if associated is None:
            image = self._slide
            if self._with_viewer:
                 basename = os.path.join(self._basename, VIEWER_SLIDE_NAME)
            else:
                basename = self._basename
        else:
            image = ImageSlide(self._slide.associated_images[associated])
            basename = os.path.join(self._basename, self._slugify(associated))
        # print("enter DeepZoomGenerator")
        dz = DeepZoomGenerator(image, self._tile_size, self._overlap,limit_bounds=self._limit_bounds)
        # print("enter DeepZoomImageTiler")
        tiler = DeepZoomImageTiler(dz, basename, self._format, associated,self._queue, self._slide, self._basenameJPG, self._xmlfile, self._mask_type, self._xmlLabel, self._ROIpc, self._ImgExtension, self._SaveMasks, self._Mag, self._normalize, self._Fieldxml)
        tiler.run()
        self._dzi_data[self._url_for(associated)] = tiler.get_dzi()



    def _url_for(self, associated):
        if associated is None:
            base = VIEWER_SLIDE_NAME
        else:
            base = self._slugify(associated)
        return '%s.dzi' % base

    def _write_html(self):
        import jinja2
        env = jinja2.Environment(loader=jinja2.PackageLoader(__name__),autoescape=True)
        template = env.get_template('slide-multipane.html')
        associated_urls = dict((n, self._url_for(n))
                for n in self._slide.associated_images)
        try:
            mpp_x = self._slide.properties[openslide.PROPERTY_NAME_MPP_X]
            mpp_y = self._slide.properties[openslide.PROPERTY_NAME_MPP_Y]
            mpp = (float(mpp_x) + float(mpp_y)) / 2
        except (KeyError, ValueError):
            mpp = 0
        # Embed the dzi metadata in the HTML to work around Chrome's
        # refusal to allow XmlHttpRequest from file:///, even when
        # the originating page is also a file:///
        data = template.render(slide_url=self._url_for(None),slide_mpp=mpp,associated=associated_urls, properties=self._slide.properties, dzi_data=json.dumps(self._dzi_data))
        with open(os.path.join(self._basename, 'index.html'), 'w') as fh:
            fh.write(data)

    def _write_static(self):
        basesrc = os.path.join(os.path.dirname(os.path.abspath(__file__)),
                'static')
        basedst = os.path.join(self._basename, 'static')
        self._copydir(basesrc, basedst)
        self._copydir(os.path.join(basesrc, 'images'),
                os.path.join(basedst, 'images'))

    def _copydir(self, src, dest):
        if not os.path.exists(dest):
            os.makedirs(dest)
        for name in os.listdir(src):
            srcpath = os.path.join(src, name)
            if os.path.isfile(srcpath):
                shutil.copy(srcpath, os.path.join(dest, name))

    @classmethod
    def _slugify(cls, text):
        text = normalize('NFKD', text.lower()).encode('ascii', 'ignore').decode()
        return re.sub('[^a-z0-9]+', '_', text)

    def _shutdown(self):
        for _i in range(self._workers):
            self._queue.put(None)
        self._queue.join()



def ImgWorker(queue):
	# print("ImgWorker started")
	while True:
		cmd = queue.get()			
		if cmd is None:
			queue.task_done()
			break
		# print("Execute: %s" % (cmd))
		subprocess.Popen(cmd, shell=True).wait()
		queue.task_done()

def xml_read_labels(xmldir, Fieldxml):
        try:
            xmlcontent = minidom.parse(xmldir)
            xml_valid = True
        except:
            xml_valid = False
            print("error with minidom.parse(xmldir)")
            return [], xml_valid
        labeltag = xmlcontent.getElementsByTagName('Attribute')
        xml_labels = []
        for xmllabel in labeltag:
            xml_labels.append(xmllabel.attributes[Fieldxml].value)
            #xml_labels.append(xmllabel.attributes['Name'].value)
            # xml_labels.append(xmllabel.attributes['Value'].value)
        if xml_labels==[]:
            xml_labels = ['']
        # print(xml_labels)
        return xml_labels, xml_valid

# %%
if __name__ == '__main__':
	parser = OptionParser(usage='Usage: %prog [options] <slide>')

	parser.add_option('-L', '--ignore-bounds', dest='limit_bounds',
		default=True, action='store_false',
		help='display entire scan area')
	parser.add_option('-e', '--overlap', metavar='PIXELS', dest='overlap',
		type='int', default=1,
		help='overlap of adjacent tiles [1]')
	parser.add_option('-f', '--format', metavar='{jpeg|png}', dest='format',
		default='jpeg',
		help='image format for tiles [jpeg]')
	parser.add_option('-j', '--jobs', metavar='COUNT', dest='workers',
		type='int', default=4,
		help='number of worker processes to start [4]')
	parser.add_option('-o', '--output', metavar='NAME', dest='basename',
		help='base name of output file')
	parser.add_option('-Q', '--quality', metavar='QUALITY', dest='quality',
		type='int', default=90,
		help='JPEG compression quality [90]')
	parser.add_option('-r', '--viewer', dest='with_viewer',
		action='store_true',
		help='generate directory tree with HTML viewer')
	parser.add_option('-s', '--size', metavar='PIXELS', dest='tile_size',
		type='int', default=254,
		help='tile size [254]')
	parser.add_option('-B', '--Background', metavar='PIXELS', dest='Bkg',
		type='float', default=50,
		help='Max background threshold [50]; percentager of background allowed')
	parser.add_option('-x', '--xmlfile', metavar='NAME', dest='xmlfile',
		help='xml file if needed')
	parser.add_option('-F', '--Fieldxml', metavar='{Name|Value}', dest='Fieldxml',
		default='Value',
		help='which field of the xml file is the label saved')
	parser.add_option('-m', '--mask_type', metavar='COUNT', dest='mask_type',
		type='int', default=1,
		help='if xml file is used, keep tile within the ROI (1) or outside of it (0)')
	parser.add_option('-R', '--ROIpc', metavar='PIXELS', dest='ROIpc',
		type='float', default=50,
		help='To be used with xml file - minimum percentage of tile covered by ROI (white)')
	parser.add_option('-l', '--oLabelref', metavar='NAME', dest='oLabelref',
		help='To be used with xml file - Only tile for label which contains the characters in oLabel')
	parser.add_option('-S', '--SaveMasks', metavar='NAME', dest='SaveMasks',
		default=False,
		help='set to yes if you want to save ALL masks for ALL tiles (will be saved in same directory with <mask> suffix)')
	parser.add_option('-t', '--tmp_dcm', metavar='NAME', dest='tmp_dcm',
		help='base name of output folder to save intermediate dcm images converted to jpg (we assume the patient ID is the folder name in which the dcm images are originally saved)')
	parser.add_option('-M', '--Mag', metavar='PIXELS', dest='Mag',
		type='float', default=-1,
		help='Magnification at which tiling should be done (-1 of all)')
	parser.add_option('-N', '--normalize', metavar='NAME', dest='normalize',
		help='if normalization is needed, N list the mean and std for each channel. For example \'57,22,-8,20,10,5\' with the first 3 numbers being the targeted means, and then the targeted stds')

(opts, args) = parser.parse_args()

opts.limit_bounds =  True
opts.quality =  90
#opts.workers = workers
#opts.with_viewer =  store_true
#opts.Bkg = Bkg 
#opts.basenameJPG  
#opts.xmlfile 
#opts.mask_type 
#opts.ROIpc 
#opts.SaveMasks
#opts.Mag 
#opts.normalize
#opts.Fieldxml
#ImgExtension





try:
	slidepath = args[0]
except IndexError:
	parser.error('Missing slide argument')
if opts.basename is None:
	opts.basename = os.path.splitext(os.path.basename(slidepath))[0]
if opts.xmlfile is None:
	opts.xmlfile = ''

try:
	if opts.normalize is not None:
		opts.normalize = [float(x) for x in opts.normalize.split(',')]
		if len(opts.normalize) != 6:
			opts.normalize = ''
			parser.error("ERROR: NO NORMALIZATION APPLIED: input vector does not have the right length - 6 values expected")
	else:
		opts.normalize  = ''

except:
	opts.normalize = ''
	parser.error("ERROR: NO NORMALIZATION APPLIED: input vector does not have the right format")
			#if ss != '':
			#    if os.path.isdir(opts.xmlfile):
# Out:
# Usage: ipykernel_launcher.py [options] <slide>
#
# ipykernel_launcher.py: error: Missing slide argument
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# Initialization
# python 00_preprocessing/0b_tileLoop_deepzoom4.py  -s 512 -e 0 -j 32 -B 50 -M 20 -o 512px_Tiled "downloaded_data/*/*svs"  
#imgExample = "/ifs/home/coudrn01/NN/Lung/RawImages/*/*svs"
tile_size = 512
overlap = 0
workers = 32
Bkg = 50
Mag = 20
basename = '512px_Tiled'
max_number_processes = 10
NbrCPU = 4
image_path = 'content/Images/*/*svs'

opts.basename = basename
opts.xmlfile = None
opts.normalize = None
opts.format = 'jpeg'
opts.tile_size = tile_size 
opts.overlap = overlap 
opts.limit_bounds =  True
opts.quality =  90




try:
  slidepath = image_path
except IndexError:
  parser.error('Missing slide argument')
if opts.basename is None:
  opts.basename = os.path.splitext(os.path.basename(slidepath))[0]
if opts.xmlfile is None:
  opts.xmlfile = ''

try:
  if opts.normalize is not None:
    opts.normalize = [float(x) for x in opts.normalize.split(',')]
    if len(opts.normalize) != 6:
      opts.normalize = ''
      parser.error("ERROR: NO NORMALIZATION APPLIED: input vector does not have the right length - 6 values expected")
  else:
    opts.normalize  = ''

except:
  opts.normalize = ''
  parser.error("ERROR: NO NORMALIZATION APPLIED: input vector does not have the right format")
      #if ss != '':
      #    if os.path.isdir(opts.xmlfile):

# get images from the data/ file.
files = glob(slidepath)  
#ImgExtension = os.path.splitext(slidepath)[1]
ImgExtension = slidepath.split('.')[-1]
print("Slidepath: ", slidepath)
print("Files: ", files)
print("ImaExtension: ", ImgExtension)
#files
#len(files)
# print(args)
# print(args[0])
# print("***********************")

'''
dz_queue = JoinableQueue()
procs = []
print("Nb of processes:")
print(opts.max_number_processes)
for i in range(opts.max_number_processes):
  p = Process(target = ImgWorker, args = (dz_queue,))
  #p.deamon = True
  p.setDaemon = True
  p.start()
  procs.append(p)
'''
# Out:
# Slidepath:  content/Images/*/*svs
# Files:  ['content/Images/5647b3ab-ae91-4bd3-8179-bcf3d1f85317/TCGA-85-A4JB-01A-05-TSE.9AF21BB3-E3E2-47CE-8BF6-025A1BC6FD96.svs', 'content/Images/2263e5d9-d2d7-4dce-a4e6-9edef7519e9e/TCGA-49-4505-11A-01-BS1.e019788b-29ba-4469-bda7-c39824386c12.svs', 'content/Images/32cc4f1b-c416-4689-980a-78624d89d4eb/TCGA-44-2655-11A-01-TS1.1f824b99-5455-4bab-b491-e993d9f370af.svs', 'content/Images/1b640e99-3ed0-42bc-8e2c-2dccf789a283/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848.svs', 'content/Images/68ea3f6b-df81-4f87-9e06-388bb786ffae/TCGA-56-8307-01A-01-TS1.7537de75-53be-4ace-aec7-0a6119eb5144.svs', 'content/Images/bcdf3222-020c-40aa-89ab-c8273bd383f2/TCGA-21-1080-01A-01-BS1.07776f13-668c-44a8-ad9e-1d967efc1c76.svs']
# ImaExtension:  content/Images/*/*svs
# '\ndz_queue = JoinableQueue()\nprocs = []\nprint("Nb of processes:")\nprint(opts.max_number_processes)\nfor i in range(opts.max_number_processes):\n  p = Process(target = ImgWorker, args = (dz_queue,))\n  #p.deamon = True\n  p.setDaemon = True\n  p.start()\n  procs.append(p)\n'

# %%
files = sorted(files)
#for imgNb in range(len(files)):
for imgNb in range(1):
  filename = files[imgNb]
  # print(filename)
  opts.basenameJPG = os.path.splitext(os.path.basename(filename))[0]
  print("processing: " + opts.basenameJPG + " with extension: " + ImgExtension)
  #opts.basenameJPG = os.path.splitext(os.path.basename(slidepath))[0]
  #if os.path.isdir("%s_files" % (basename)):
    #print("EXISTS")
  #else:
    #print("Not Found")

  if ("dcm" in ImgExtension) :
    print("convert %s dcm to jpg" % filename)
    if opts.tmp_dcm is None:
      parser.error('Missing output folder for dcm>jpg intermediate files')
    elif not os.path.isdir(opts.tmp_dcm):
      parser.error('Missing output folder for dcm>jpg intermediate files')

    if filename[-3:] == 'jpg':
                          continue
    ImageFile=dicom.read_file(filename)
    im1 = ImageFile.pixel_array
    maxVal = float(im1.max())
    minVal = float(im1.min())
    height = im1.shape[0]
    width = im1.shape[1]
    image = np.zeros((height,width,3), 'uint8')
    image[...,0] = ((im1[:,:].astype(float) - minVal)  / (maxVal - minVal) * 255.0).astype(int)
    image[...,1] = ((im1[:,:].astype(float) - minVal)  / (maxVal - minVal) * 255.0).astype(int)
    image[...,2] = ((im1[:,:].astype(float) - minVal)  / (maxVal - minVal) * 255.0).astype(int)
    # dcm_ID = os.path.basename(os.path.dirname(filename))
    # opts.basenameJPG = dcm_ID + "_" + opts.basenameJPG
    filename = os.path.join(opts.tmp_dcm, opts.basenameJPG + ".jpg")
    # print(filename)
    imsave(filename,image)

    output = os.path.join(opts.basename, opts.basenameJPG)

    try:
      DeepZoomStaticTiler(filename, output, opts.format, opts.tile_size, opts.overlap, opts.limit_bounds, opts.quality, opts.workers, opts.with_viewer, opts.Bkg, opts.basenameJPG, opts.xmlfile, opts.mask_type, opts.ROIpc, '', ImgExtension, opts.SaveMasks, opts.Mag, opts.normalize, opts.Fieldxml).run()
    except Exception as e:
      print("Failed to process file %s, error: %s" % (filename, sys.exc_info()[0]))
      print(e)

  #elif ("jpg" in ImgExtension) :
  #	output = os.path.join(opts.basename, opts.basenameJPG)
  #	if os.path.exists(output + "_files"):
  #		print("Image %s already tiled" % opts.basenameJPG)
  #		continue

  #	DeepZoomStaticTiler(filename, output, opts.format, opts.tile_size, opts.overlap, opts.limit_bounds, opts.quality, opts.workers, opts.with_viewer, opts.Bkg, opts.basenameJPG, opts.xmlfile, opts.mask_type, opts.ROIpc, '', ImgExtension, opts.SaveMasks, opts.Mag, opts.normalize, opts.Fieldxml).run()

  elif opts.xmlfile != '':
    xmldir = os.path.join(opts.xmlfile, opts.basenameJPG + '.xml')
    # print("xml:")
    # print(xmldir)
    if os.path.isfile(xmldir):
      if (opts.mask_type==1) or (opts.oLabelref!=''):
        # either mask inside ROI, or mask outside but a reference label exist
        xml_labels, xml_valid = xml_read_labels(xmldir, opts.Fieldxml)
        if (opts.mask_type==1):
          # No inverse mask
          Nbr_ROIs_ForNegLabel = 1
        elif (opts.oLabelref!=''):
          # Inverse mask and a label reference exist
          Nbr_ROIs_ForNegLabel = 0

        for oLabel in xml_labels:
          # print("label is %s and ref is %s" % (oLabel, opts.oLabelref))
          if (opts.oLabelref in oLabel) or (opts.oLabelref==''):
            # is a label is identified 
            if (opts.mask_type==0):
              # Inverse mask and label exist in the image
              Nbr_ROIs_ForNegLabel += 1
              # there is a label, and map is to be inverted
              output = os.path.join(opts.basename, oLabel+'_inv', opts.basenameJPG)
              if not os.path.exists(os.path.join(opts.basename, oLabel+'_inv')):
                os.makedirs(os.path.join(opts.basename, oLabel+'_inv'))
            else:
              Nbr_ROIs_ForNegLabel += 1
              output = os.path.join(opts.basename, oLabel, opts.basenameJPG)
              if not os.path.exists(os.path.join(opts.basename, oLabel)):
                os.makedirs(os.path.join(opts.basename, oLabel))
            if 1:
            #try:
              DeepZoomStaticTiler(filename, output, opts.format, opts.tile_size, opts.overlap, opts.limit_bounds, opts.quality, opts.workers, opts.with_viewer, opts.Bkg, opts.basenameJPG, opts.xmlfile, opts.mask_type, opts.ROIpc, oLabel, ImgExtension, opts.SaveMasks, opts.Mag, opts.normalize, opts.Fieldxml).run()
            #except:
            #	print("Failed to process file %s, error: %s" % (filename, sys.exc_info()[0]))
          if Nbr_ROIs_ForNegLabel==0:
            print("label %s is not in that image; invert everything" % (opts.oLabelref))
            # a label ref was given, and inverse mask is required but no ROI with this label in that map --> take everything
            oLabel = opts.oLabelref
            output = os.path.join(opts.basename, opts.oLabelref+'_inv', opts.basenameJPG)
            if not os.path.exists(os.path.join(opts.basename, oLabel+'_inv')):
              os.makedirs(os.path.join(opts.basename, oLabel+'_inv'))
            if 1:
            #try:
              DeepZoomStaticTiler(filename, output, opts.format, opts.tile_size, opts.overlap, opts.limit_bounds, opts.quality, opts.workers, opts.with_viewer, opts.Bkg, opts.basenameJPG, opts.xmlfile, opts.mask_type, opts.ROIpc, oLabel, ImgExtension, opts.SaveMasks, opts.Mag, opts.normalize, opts.Fieldxml).run()
            #except:
            #	print("Failed to process file %s, error: %s" % (filename, sys.exc_info()[0]))

      else:
        # Background
        oLabel = "non_selected_regions"
        output = os.path.join(opts.basename, oLabel, opts.basenameJPG)
        if not os.path.exists(os.path.join(opts.basename, oLabel)):
          os.makedirs(os.path.join(opts.basename, oLabel))
        try:
          DeepZoomStaticTiler(filename, output, opts.format, opts.tile_size, opts.overlap, opts.limit_bounds, opts.quality, opts.workers, opts.with_viewer, opts.Bkg, opts.basenameJPG, opts.xmlfile, opts.mask_type, opts.ROIpc, oLabel, ImgExtension, opts.SaveMasks, opts.Mag, opts.normalize, opts.Fieldxml).run()
        except Exception as e:
          print("Failed to process file %s, error: %s" % (filename, sys.exc_info()[0]))
          print(e)

    else:
      if (ImgExtension == ".jpg") | (ImgExtension == ".dcm") :
        print("Input image to be tiled is jpg or dcm and not svs - will be treated as such")
        output = os.path.join(opts.basename, opts.basenameJPG)
        try:
          DeepZoomStaticTiler(filename, output, opts.format, opts.tile_size, opts.overlap, opts.limit_bounds, opts.quality, opts.workers, opts.with_viewer, opts.Bkg, opts.basenameJPG, opts.xmlfile, opts.mask_type, opts.ROIpc, '', ImgExtension, opts.SaveMasks, opts.Mag, opts.normalize, opts.Fieldxml).run()
        except Exception as e:
          print("Failed to process file %s, error: %s" % (filename, sys.exc_info()[0]))
          print(e)


      else:
        print("No xml file found for slide %s.svs (expected: %s). Directory or xml file does not exist" %  (opts.basenameJPG, xmldir) )
        continue
  else:
    output = os.path.join(opts.basename, opts.basenameJPG)
    if os.path.exists(output + "_files"):
      print("Image %s already tiled" % opts.basenameJPG)
      continue
    try:
    #if True:
      DeepZoomStaticTiler(filename, output, opts.format, opts.tile_size, opts.overlap, opts.limit_bounds, opts.quality, opts.workers, opts.with_viewer, opts.Bkg, opts.basenameJPG, opts.xmlfile, opts.mask_type, opts.ROIpc, '', ImgExtension, opts.SaveMasks, opts.Mag, opts.normalize, opts.Fieldxml).run()
    except Exception as e:
      print("Failed to process file %s, error: %s" % (filename, sys.exc_info()[0]))
      print(e)
'''
dz_queue.join()
for i in range(opts.max_number_processes):
  dz_queue.put( None )
'''

print("End")
# Out:
# processing: TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848 with extension: content/Images/*/*svs
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 400/20446 tiles
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 500/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 600/20446 tiles
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 700/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 800/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 900/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 1000/20446 tiles
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 1100/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 1200/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 1300/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 1600/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 1700/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 2000/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 2100/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 2200/20446 tiles
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 2300/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 2400/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 2500/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 2600/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 2700/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 2800/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 2900/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 3000/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 3100/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 3200/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 3300/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 3400/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 3500/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 3600/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 3700/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 3800/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 3900/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 4000/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 4100/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 4200/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 4300/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 4400/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 4500/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 4600/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 4700/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# ...
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 19500/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 19600/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 19700/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 19800/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 19900/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 20200/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 20300/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 20400/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# Tiling slide: wrote 20446/20446 tiles
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# PercentMasked: 1.000000, 0.500000
# image content/Images/1b640e99-3ed0-42bc-8e2c-2dccf789a283/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848.svs failed at dz.get_tile for level 0.000000
# division by zero
# End

# %%
# !tar -czvf tiled_with_magnification.tar.gz '/content/512px_Tiled'
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/31_14.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/48_43.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/69_43.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/86_40.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/99_82.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/91_40.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/9_36.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/92_60.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/108_49.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/84_58.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/62_57.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/104_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/27_17.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/79_45.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/108_103.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/93_45.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/106_61.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/8_38.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/111_66.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/80_74.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/109_56.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/91_103.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/98_97.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/92_80.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/31_83.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/12_45.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/112_99.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/31_82.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/94_41.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/33_49.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/78_88.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/50_74.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/15_36.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/59_70.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/92_55.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/122_53.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/26_18.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/18_29.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/47_90.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/38_68.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/107_68.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/16_20.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/13_38.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/112_56.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/105_39.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/63_38.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/83_89.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/21_64.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/118_85.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/123_67.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/35_73.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/114_48.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/118_57.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/94_61.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/16_19.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/60_38.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/18_44.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/100_54.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/122_57.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/89_46.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/77_24.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/48_34.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/123_71.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/110_95.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/44_64.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/23_26.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/110_31.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/27_46.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/50_28.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/97_86.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/99_59.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/66_60.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/126_43.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/67_72.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/97_24.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/30_21.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/25_51.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/33_67.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/32_51.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/32_19.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/85_92.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/91_29.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/87_41.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/114_32.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/6_47.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/38_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/12_38.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/82_58.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/93_40.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/35_42.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/8_40.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/59_57.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/94_63.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/36_82.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/118_94.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/64_77.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/93_61.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/68_48.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/105_31.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/25_35.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/106_98.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/93_62.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/31_15.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/122_76.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/57_95.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/111_30.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/19_66.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/30_22.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/101_39.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/5_49.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/42_37.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/126_38.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/19_55.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/125_63.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/133_27.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/99_45.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/63_73.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/45_35.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/16_49.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/12_47.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/49_71.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/46_70.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/33_70.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/105_44.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/102_87.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/72_51.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/28_76.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/43_44.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/57_36.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/55_59.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/59_73.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/94_79.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/17_26.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/86_31.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/65_63.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/40_45.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/103_36.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/58_47.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/82_43.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/74_56.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/109_41.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/97_45.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/46_37.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/56_38.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/64_47.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/27_38.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/12_40.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/45_14.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/71_46.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/95_38.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/41_56.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/52_49.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/77_46.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/108_64.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/5_46.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/103_48.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/116_85.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/87_56.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/29_64.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/115_67.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/47_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/94_86.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/10_47.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/109_102.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/112_39.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/103_59.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/15_25.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/31_75.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/104_96.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/96_47.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/91_95.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/91_104.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/119_34.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/103_104.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/81_38.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/113_65.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/109_26.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/71_39.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/40_42.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/48_69.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/56_74.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/78_82.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/16_61.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/35_13.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/40_48.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/109_89.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/33_56.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/14_36.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/17_21.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/103_90.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/83_87.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/100_62.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/19_36.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/69_32.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/70_45.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/25_60.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/10_32.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/42_70.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/89_36.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/114_62.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/90_74.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/107_32.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/121_91.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/75_51.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/124_57.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/46_57.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/62_63.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/60_62.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/87_80.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/77_36.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/37_48.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/86_79.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/85_75.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/65_27.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/97_90.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/58_60.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/20_61.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/115_76.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/122_82.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/71_38.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/35_16.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/75_81.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/89_44.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/70_52.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/60_52.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/117_59.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/94_47.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/67_66.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/108_20.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/109_98.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/38_77.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/14_31.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/75_54.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/107_93.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/56_45.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/85_72.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/108_88.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/87_28.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/40_50.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/44_8.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/89_45.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/11_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/111_88.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/84_72.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/78_80.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/65_75.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/90_49.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/74_30.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/10_50.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/18_57.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/30_39.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/32_40.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/61_50.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/104_28.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/45_69.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/68_49.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/94_60.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/97_52.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/86_59.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/112_31.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/80_109.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/69_51.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/23_40.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/35_69.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/93_67.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/61_77.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/28_74.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/66_56.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/38_49.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/94_75.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/62_71.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/115_77.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/10_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/90_92.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/23_30.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/29_81.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/77_37.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/112_54.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/107_60.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/33_19.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/43_9.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/44_73.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/108_91.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/124_50.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/88_76.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/84_43.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/94_101.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/67_65.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/37_54.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/82_25.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/95_73.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/70_38.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/51_49.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/83_79.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/103_28.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/93_81.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/126_45.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/47_47.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/66_53.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/106_67.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/108_35.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/39_71.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/69_29.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/71_60.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/92_58.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/96_84.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/22_64.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/109_43.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/92_98.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/89_92.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/82_30.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/88_24.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/65_67.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/32_43.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/68_71.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/23_51.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/125_43.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/90_23.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/58_70.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/112_97.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/120_51.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/18_43.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/87_81.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/49_7.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/105_80.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/65_54.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/30_52.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/116_79.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/81_62.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/32_62.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/92_36.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/102_51.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/33_41.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/68_57.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/75_50.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/8_47.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/41_53.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/117_91.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/67_51.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/123_56.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/41_73.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/20_27.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/117_81.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/87_44.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/78_53.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/67_37.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/115_80.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/89_34.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/15_49.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/96_37.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/85_85.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/79_84.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/58_39.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/85_77.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/36_39.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/112_53.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/34_34.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/108_23.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/82_52.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/64_37.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/27_18.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/68_35.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/49_27.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/109_59.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/79_36.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/24_39.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/26_62.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/122_39.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/102_47.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/8_53.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/122_90.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/88_53.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/19_52.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/27_16.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/36_77.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/57_41.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/119_63.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/70_76.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/125_71.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/84_87.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/27_43.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/15_40.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/30_75.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/36_81.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/99_27.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/86_73.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/86_56.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/94_73.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/99_31.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/98_86.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/99_50.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/57_69.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/4_41.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/28_40.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/118_91.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/84_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/122_65.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/71_62.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/96_46.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/58_62.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/43_45.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/88_67.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/52_96.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/117_84.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/68_75.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/44_38.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/46_76.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/126_72.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/34_69.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/66_74.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/35_62.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/80_28.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/96_72.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/77_61.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/7_34.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/53_75.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/49_36.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/50_76.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/81_49.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/40_30.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/110_50.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/96_88.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/122_84.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/72_37.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/33_60.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/6_41.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/88_51.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/48_72.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/81_41.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/44_7.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/96_63.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/124_84.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/24_16.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/114_65.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/85_74.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/12_31.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/13_59.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/125_76.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/116_97.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/87_57.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/118_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/95_57.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/90_61.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/74_32.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/3_47.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/58_65.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/68_72.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/16_23.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/5_50.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/115_63.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/102_67.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/47_51.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/54_59.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/114_88.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/111_60.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/20_65.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/56_71.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/51_66.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/62_66.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/40.0/45_60.jpeg
# ...
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/38_23.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/13_26.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/1_25.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/27_29.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/39_54.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/7_30.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/19_22.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/9_17.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/43_36.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/57_27.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/1_23.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/24_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/46_21.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/52_26.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/25_31.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/33_36.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/50_18.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/47_15.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/44_32.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/52_21.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/29_38.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/56_41.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/33_17.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/60_45.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/44_19.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/26_24.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/22_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/23_17.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/18_30.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/61_40.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/48_28.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/34_41.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/25_29.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/60_40.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/10_8.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/38_37.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/4_14.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/59_22.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/42_14.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/20_20.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/25_5.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/58_22.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/18_39.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/7_28.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/25_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/25_3.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/28_19.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/40_13.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/2_16.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/49_30.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/0_23.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/18_10.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/23_19.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/20_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/33_40.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/34_32.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/45_24.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/16_34.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/10_10.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/51_10.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/31_28.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/33_12.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/52_17.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/29_20.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/43_39.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/46_32.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/41_44.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/46_35.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/31_25.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/40_22.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/7_29.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/38_43.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/21_36.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/55_14.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/55_12.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/47_20.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/42_24.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/28_23.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/38_42.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/55_48.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/16_35.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/20_25.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/54_32.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/35_20.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/11_27.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/5_13.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/53_43.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/32_37.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/16_24.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/11_12.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/53_18.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/45_39.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/24_34.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/41_45.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/12_24.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/61_35.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/39_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/15_29.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/4_26.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/48_14.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/49_47.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/6_17.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/16_25.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/41_37.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/41_21.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/57_19.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/61_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/57_24.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/18_18.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/47_27.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/11_7.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/48_37.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/44_42.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/35_35.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/41_22.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/46_26.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/31_37.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/21_32.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/21_19.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/51_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/38_40.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/44_33.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/26_30.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/18_28.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/30_14.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/11_25.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/12_15.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/55_21.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/24_45.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/12_22.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/59_41.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/7_15.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/49_23.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/12_17.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/51_37.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/50_39.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/13_27.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/20.0/41_43.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/0.625/
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/0.625/1_0.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/0.625/0_0.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/0.625/1_1.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/0.0006103515625/
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/0.0006103515625/0_0.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/1.25/
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/1.25/2_2.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/1.25/1_1.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/1.25/3_1.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/1.25/2_1.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/1.25/0_1.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/1.25/3_2.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/0.01953125/
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848_files/0.01953125/0_0.jpeg
# /content/512px_Tiled/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848.dzi

# %%
# !tar -czvf six_cases_svs.tar.gz '/content/content'
# Out:
# tar: Removing leading `/' from member names
# /content/content/
# /content/content/Images/
# /content/content/Images/5647b3ab-ae91-4bd3-8179-bcf3d1f85317/
# /content/content/Images/5647b3ab-ae91-4bd3-8179-bcf3d1f85317/logs/
# /content/content/Images/5647b3ab-ae91-4bd3-8179-bcf3d1f85317/logs/TCGA-85-A4JB-01A-05-TSE.9AF21BB3-E3E2-47CE-8BF6-025A1BC6FD96.svs.parcel
# /content/content/Images/5647b3ab-ae91-4bd3-8179-bcf3d1f85317/TCGA-85-A4JB-01A-05-TSE.9AF21BB3-E3E2-47CE-8BF6-025A1BC6FD96.svs
# /content/content/Images/2263e5d9-d2d7-4dce-a4e6-9edef7519e9e/
# /content/content/Images/2263e5d9-d2d7-4dce-a4e6-9edef7519e9e/TCGA-49-4505-11A-01-BS1.e019788b-29ba-4469-bda7-c39824386c12.svs
# /content/content/Images/2263e5d9-d2d7-4dce-a4e6-9edef7519e9e/logs/
# /content/content/Images/2263e5d9-d2d7-4dce-a4e6-9edef7519e9e/logs/TCGA-49-4505-11A-01-BS1.e019788b-29ba-4469-bda7-c39824386c12.svs.parcel
# /content/content/Images/32cc4f1b-c416-4689-980a-78624d89d4eb/
# /content/content/Images/32cc4f1b-c416-4689-980a-78624d89d4eb/TCGA-44-2655-11A-01-TS1.1f824b99-5455-4bab-b491-e993d9f370af.svs
# /content/content/Images/32cc4f1b-c416-4689-980a-78624d89d4eb/logs/
# /content/content/Images/32cc4f1b-c416-4689-980a-78624d89d4eb/logs/TCGA-44-2655-11A-01-TS1.1f824b99-5455-4bab-b491-e993d9f370af.svs.parcel
# /content/content/Images/1b640e99-3ed0-42bc-8e2c-2dccf789a283/
# /content/content/Images/1b640e99-3ed0-42bc-8e2c-2dccf789a283/logs/
# /content/content/Images/1b640e99-3ed0-42bc-8e2c-2dccf789a283/logs/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848.svs.parcel
# /content/content/Images/1b640e99-3ed0-42bc-8e2c-2dccf789a283/TCGA-86-8674-01A-01-BS1.c44d998a-4341-4348-8813-c2b94ffba848.svs
# /content/content/Images/68ea3f6b-df81-4f87-9e06-388bb786ffae/
# /content/content/Images/68ea3f6b-df81-4f87-9e06-388bb786ffae/logs/
# /content/content/Images/68ea3f6b-df81-4f87-9e06-388bb786ffae/logs/TCGA-56-8307-01A-01-TS1.7537de75-53be-4ace-aec7-0a6119eb5144.svs.parcel
# /content/content/Images/68ea3f6b-df81-4f87-9e06-388bb786ffae/TCGA-56-8307-01A-01-TS1.7537de75-53be-4ace-aec7-0a6119eb5144.svs
# /content/content/Images/bcdf3222-020c-40aa-89ab-c8273bd383f2/
# /content/content/Images/bcdf3222-020c-40aa-89ab-c8273bd383f2/TCGA-21-1080-01A-01-BS1.07776f13-668c-44a8-ad9e-1d967efc1c76.svs
# /content/content/Images/bcdf3222-020c-40aa-89ab-c8273bd383f2/logs/
# /content/content/Images/bcdf3222-020c-40aa-89ab-c8273bd383f2/logs/TCGA-21-1080-01A-01-BS1.07776f13-668c-44a8-ad9e-1d967efc1c76.svs.parcel

# %%
# !cp *.gz '/content/drive/MyDrive/GDC'

# %%
# !mkdir r1_sorted_3Cla

# %%
# %cd r1_sorted_3Cla
# Out:
# /content/r1_sorted_3Cla

# %%
# !python 0d_SortTiles.py --SourceFolder='../512px_Tiled/' --Magnification=20.0  --MagDiffAllowed=0 --SortingOption=3  --PatientID=12 --nSplit 0 --JsonFile='../downloaded_data/metadata.cart.2017-03-02T00_36_30.276824.json' --PercentTest=15 --PercentValid=15
